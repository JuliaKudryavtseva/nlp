# %%
# !nvidia-smi
# Out:
# Mon Feb 27 10:11:35 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.86.01    Driver Version: 515.86.01    CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:E1:00.0 Off |                  N/A |
# |  0%   25C    P8    25W / 370W |      2MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install torch
# !pip install transformers
# Out:
# Collecting torch
#   Downloading torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl (887.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 3.2 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 52.0 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 6.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.4.0)
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 4.8 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 22.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: wheel in /opt/conda/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.38.4)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (67.3.2)
# Installing collected packages: nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, nvidia-cudnn-cu11, torch
# Successfully installed nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 torch-1.13.1
# Collecting transformers
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 18.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.28.2)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 43.1 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.64.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.23.5)
# Collecting filelock
#   Downloading filelock-3.9.0-py3-none-any.whl (9.7 kB)
# Collecting regex!=2019.12.17
#   Downloading regex-2022.10.31-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (770 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.5/770.5 kB 57.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.12.1-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 kB 29.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2022.12.7)
# Installing collected packages: tokenizers, regex, filelock, huggingface-hub, transformers
# Successfully installed filelock-3.9.0 huggingface-hub-0.12.1 regex-2022.10.31 tokenizers-0.13.2 transformers-4.26.1

# %%
import numpy as np
import torch

from transformers import T5ForConditionalGeneration, AutoTokenizer
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, AutoConfig


from torch.utils.data import Dataset, DataLoader
from transformers import Trainer, TrainingArguments
from transformers.file_utils import cached_property
from typing import Tuple
from sklearn.model_selection import train_test_split
import gc
from tqdm.auto import tqdm, trange


import pandas as pd
from sklearn.utils import shuffle

from collections import Counter
from tqdm import tqdm

# %% [markdown]
# # model

# %%
if torch.cuda.is_available():
    device='cuda:0'
    print('GPU')
else:
    device='cpu'
    print('CPU')
    
    
SEED = 0
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
# Out:
# GPU

# %%
from transformers import TrainingArguments, Trainer

model_checkpoint = "t5-large"
model = T5ForConditionalGeneration.from_pretrained(model_checkpoint).to(device)
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/2.95G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/transformers/models/t5/tokenization_t5_fast.py:155: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-large automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(

# %%
class PairsDataset(torch.utils.data.Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __getitem__(self, idx):
        assert idx <= len(self.x['input_ids']), (idx, len(self.x['input_ids']))
        item = {key: val[idx] for key, val in self.x.items()}
        item['decoder_attention_mask'] = self.y['attention_mask'][idx]
        item['labels'] = self.y['input_ids'][idx]
        return item
    
    @property
    def n(self):
        return len(self.x['input_ids'])

    def __len__(self):
        return self.n

# %%
from typing import List, Dict, Union

class DataCollatorWithPadding:
    def __init__(self, tokenizer):
        self.tokenizer = tokenizer

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        batch = self.tokenizer.pad(
            features,
            padding=True,
        )
        ybatch = self.tokenizer.pad(
            {'input_ids': batch['labels'], 'attention_mask': batch['decoder_attention_mask']},
            padding=True,
        ) 
        batch['labels'] = ybatch['input_ids']
        batch['decoder_attention_mask'] = ybatch['attention_mask']
        
        return {k: torch.tensor(v) for k, v in batch.items()}

# %%
def cleanup():
    gc.collect()
    torch.cuda.empty_cache()
    
cleanup()

# %%
def evaluate_model(model, test_dataloader):
    num = 0
    den = 0

    for batch in test_dataloader:
        with torch.no_grad():
            loss = model(**{k: v.to(model.device) for k, v in batch.items()}).loss
            num += len(batch) * loss.item()
            den += len(batch)
    val_loss = num / den
    return val_loss

# %% [markdown]
# # **Read data SemEval2018-Task9**

# %%
path_data_en = "SemEval2018-Task9/training/data/1A.english.training.data.txt"
path_gold_en = "SemEval2018-Task9/training/gold/1A.english.training.gold.txt"

train_data_en_data = pd.read_csv(path_data_en, header=None, sep="\t", names=['term', 'relation'])
train_gold_en_data = pd.read_csv(path_gold_en, header=None, names=['hypernym'])

train_data_en_data.head()
# Out:
#              term relation
# 0        blackfly  Concept
# 1        Turonian   Entity
# 2      abhorrence  Concept
# 3  tropical storm  Concept
# 4  militarization  Concept

# %%
path_test_data_en = "SemEval2018-Task9/test/data/1A.english.test.data.txt"
path_test_gold_en = "SemEval2018-Task9/test/gold/1A.english.test.gold.txt"

test_data_en_data = pd.read_csv(path_test_data_en, header=None, sep="\t", names=['term', 'relation'])
test_gold_en_data = pd.read_csv(path_test_gold_en, header=None, names=['hypernym'])

# %%
def embading_find_hyponyms_uppercase(train_features, train_target, test_features, test_target):
    
    train_data_en = train_features.copy()
    train_data_en = 'find hyponyms for hyperonym: ' + train_data_en.term + ' , target:'
    print(train_data_en.head())

    train_gold_en = train_target.copy()
    train_gold_en = train_gold_en.hypernym.str.split('\t').str.join(', ')
    print(train_gold_en.head())
    
    test_data_en = test_features.copy()
    test_data_en = 'find hyponyms for hyperonym: ' + test_data_en.term + ' , target:'
    print(test_data_en.head())

    test_gold_en = test_target.copy()
    test_gold_en = test_gold_en.hypernym.str.split('\t').str.join(', ')
    print(test_gold_en.head())
    
    return train_data_en, train_gold_en, test_data_en, test_gold_en

# %%
train_data_en, train_gold_en, test_data_en, test_gold_en = embading_find_hyponyms_uppercase(train_data_en_data, 
                                                                                 train_gold_en_data, 
                                                                                 test_data_en_data, 
                                                                                 test_gold_en_data)

# %% [markdown]
# # Model training embading_find_hyponyms_uppercase

# %%
# use only 1 time per session
model_checkpoint = "t5-large"
model = T5ForConditionalGeneration.from_pretrained(model_checkpoint).to(device)
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint, max_length=100, block_size=64)
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/models/t5/tokenization_t5_fast.py:155: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-large automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(

# %%
train_dataset = PairsDataset(tokenizer(train_data_en.tolist()), tokenizer(train_gold_en.tolist()))
test_dataset = PairsDataset(tokenizer(test_data_en.tolist()), tokenizer(test_gold_en.tolist()))
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

args = TrainingArguments(output_dir="t5-finetuned-large", 
                         num_train_epochs=16, 
                         per_device_train_batch_size=16, save_steps=10000)

trainer = Trainer(
    model = model,
    args = args,
    train_dataset = train_dataset,
    eval_dataset = test_dataset,
    tokenizer = tokenizer,
    data_collator = data_collator
)

# %%
trainer.train()
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 1500
#   Num Epochs = 16
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1504
#   Number of trainable parameters = 737668096
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='1504' max='1504' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1504/1504 09:22, Epoch 16/16]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.952200</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.649800</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.579400</td>
#     </tr>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=1504, training_loss=0.7269695131702626, metrics={'train_runtime': 576.4958, 'train_samples_per_second': 41.631, 'train_steps_per_second': 2.609, 'total_flos': 2052887697408000.0, 'train_loss': 0.7269695131702626, 'epoch': 16.0})

# %%
# !nvidia-smi
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Sun Feb 26 17:54:18 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.86.01    Driver Version: 515.86.01    CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:E1:00.0 Off |                  N/A |
# | 74%   53C    P2   179W / 370W |  24213MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # EVALUATION

# %%
def predict(test_data_en, test_gold_en):
    test_pred_en=[]
    for i_2, j_2 in tqdm(zip(test_data_en.tolist(), test_gold_en.tolist())):
            input_ids = tokenizer.encode(i_2, return_tensors="pt")
            output_batch = model.generate(input_ids.cuda(), no_repeat_ngram_size=2, max_new_tokens=2048, 
                                          num_return_sequences=50, num_beams=50, early_stopping=True, 
                                          num_beam_groups=5, 
                                          diversity_penalty=1.0)
            decoded_list = []
            for outputs in output_batch:
                decoded = tokenizer.decode(outputs, skip_special_tokens=True).split(", ")
                decoded_list.extend(decoded)

            sorted_predicted_answer = [i[0] for i in Counter(decoded_list).most_common()]

            test_pred_en.append(sorted_predicted_answer)
    return test_pred_en

# %%
test_pred_en = predict(test_data_en, test_gold_en)
# Out:
# 0it [00:00, ?it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1it [00:00,  2.42it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 2it [00:00,  3.06it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 3it [00:01,  2.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 4it [00:01,  2.84it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 5it [00:01,  3.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 6it [00:01,  3.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 7it [00:02,  3.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 8it [00:02,  3.61it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 9it [00:02,  3.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 10it [00:03,  3.35it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 11it [00:03,  3.45it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 12it [00:03,  3.27it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 13it [00:04,  3.05it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 14it [00:04,  3.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 15it [00:04,  3.45it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 16it [00:04,  3.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 17it [00:05,  3.46it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 18it [00:05,  3.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 19it [00:05,  3.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 20it [00:06,  3.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 21it [00:06,  3.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 22it [00:06,  3.50it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 23it [00:07,  3.45it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 24it [00:07,  3.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 25it [00:08,  2.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 26it [00:08,  2.45it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 27it [00:08,  2.61it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 28it [00:09,  2.73it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 29it [00:09,  3.07it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 30it [00:09,  3.18it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 31it [00:10,  2.68it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 32it [00:10,  2.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 33it [00:10,  2.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 34it [00:11,  2.76it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 35it [00:11,  2.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 36it [00:12,  2.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 37it [00:12,  2.84it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 38it [00:12,  3.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 39it [00:12,  3.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 40it [00:13,  3.51it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 41it [00:13,  3.50it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 42it [00:13,  3.78it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 43it [00:14,  3.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 44it [00:14,  3.64it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 45it [00:14,  3.73it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 46it [00:14,  3.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 47it [00:15,  3.60it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 48it [00:15,  3.70it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 49it [00:15,  3.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 50it [00:16,  3.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 51it [00:16,  3.23it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 52it [00:16,  3.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 53it [00:17,  3.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 54it [00:17,  3.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 55it [00:17,  3.08it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 56it [00:18,  3.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 57it [00:18,  3.00it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 58it [00:18,  3.31it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 59it [00:18,  3.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 60it [00:19,  3.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 61it [00:19,  3.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 62it [00:19,  3.49it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 63it [00:19,  3.62it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 64it [00:20,  3.72it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 65it [00:20,  3.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 66it [00:20,  3.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 67it [00:21,  3.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 68it [00:21,  2.71it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 69it [00:22,  2.78it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 70it [00:22,  2.62it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 71it [00:22,  2.67it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 72it [00:23,  3.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 73it [00:23,  3.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 74it [00:23,  2.99it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 75it [00:24,  2.72it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 76it [00:24,  2.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 77it [00:25,  2.67it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 78it [00:25,  2.96it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 79it [00:25,  3.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 80it [00:25,  3.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 81it [00:26,  3.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 82it [00:26,  3.05it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 83it [00:26,  3.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 84it [00:27,  2.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 85it [00:28,  2.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 86it [00:28,  2.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 87it [00:28,  2.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 88it [00:29,  2.62it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 89it [00:29,  2.88it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 90it [00:29,  2.68it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 91it [00:30,  2.72it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 92it [00:30,  2.90it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 93it [00:30,  2.87it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 94it [00:31,  3.03it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 95it [00:31,  3.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 96it [00:31,  3.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 97it [00:31,  3.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 98it [00:32,  3.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 99it [00:32,  3.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 100it [00:32,  3.79it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 101it [00:32,  3.74it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 102it [00:33,  3.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 103it [00:33,  3.44it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 104it [00:34,  2.66it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 105it [00:34,  2.71it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 106it [00:34,  3.00it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 107it [00:34,  3.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 108it [00:35,  3.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 109it [00:35,  3.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 110it [00:35,  3.57it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 111it [00:36,  3.69it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 112it [00:36,  3.71it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 113it [00:36,  3.91it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 114it [00:36,  3.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 115it [00:37,  3.04it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 116it [00:37,  2.80it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 117it [00:37,  3.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 118it [00:38,  3.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 119it [00:38,  3.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 120it [00:39,  2.89it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 121it [00:39,  3.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 122it [00:39,  2.87it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 123it [00:39,  3.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 124it [00:40,  2.74it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 125it [00:40,  2.84it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 126it [00:40,  3.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 127it [00:41,  3.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 128it [00:41,  2.88it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 129it [00:41,  3.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 130it [00:42,  3.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 131it [00:42,  3.11it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 132it [00:42,  3.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 133it [00:43,  3.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 134it [00:43,  3.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 135it [00:43,  3.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 136it [00:44,  3.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 137it [00:44,  3.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 138it [00:44,  3.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 139it [00:45,  2.96it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 140it [00:45,  2.90it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 141it [00:45,  2.71it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 142it [00:46,  2.89it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 143it [00:46,  2.89it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 144it [00:46,  3.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 145it [00:47,  3.05it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 146it [00:47,  3.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 147it [00:47,  3.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 148it [00:47,  3.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 149it [00:48,  2.86it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 150it [00:48,  2.61it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 151it [00:49,  2.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 152it [00:49,  2.59it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 153it [00:49,  2.79it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 154it [00:50,  2.78it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 155it [00:50,  2.80it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 156it [00:51,  2.76it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 157it [00:51,  2.74it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 158it [00:51,  2.82it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 159it [00:51,  3.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 160it [00:52,  3.27it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 161it [00:52,  3.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 162it [00:52,  3.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 163it [00:53,  3.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 164it [00:53,  3.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 165it [00:53,  3.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 166it [00:54,  3.11it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 167it [00:54,  3.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 168it [00:54,  3.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 169it [00:55,  3.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 170it [00:55,  3.11it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 171it [00:55,  3.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 172it [00:55,  3.45it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 173it [00:56,  3.59it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 174it [00:56,  3.56it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 175it [00:56,  3.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 176it [00:57,  3.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 177it [00:57,  3.81it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 178it [00:57,  4.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 179it [00:57,  3.81it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 180it [00:58,  3.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 181it [00:58,  3.41it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 182it [00:58,  3.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 183it [00:59,  3.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 184it [00:59,  3.83it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 185it [00:59,  3.77it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 186it [00:59,  3.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 187it [01:00,  3.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 188it [01:00,  3.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 189it [01:00,  3.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 190it [01:01,  3.62it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 191it [01:01,  3.67it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 192it [01:01,  3.75it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 193it [01:01,  3.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 194it [01:02,  3.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 195it [01:02,  2.88it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 196it [01:02,  2.93it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 197it [01:03,  3.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 198it [01:03,  3.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 199it [01:03,  3.11it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 200it [01:04,  3.11it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 201it [01:04,  3.59it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 202it [01:04,  3.70it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 203it [01:04,  3.59it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 204it [01:05,  3.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 205it [01:05,  3.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 206it [01:05,  3.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 207it [01:06,  3.46it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 208it [01:06,  3.75it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 209it [01:06,  3.98it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 210it [01:06,  3.81it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 211it [01:07,  3.86it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 212it [01:07,  4.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 213it [01:07,  3.68it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 214it [01:07,  3.77it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 215it [01:08,  3.94it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 216it [01:08,  3.49it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 217it [01:08,  3.62it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 218it [01:08,  3.57it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 219it [01:09,  3.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 220it [01:09,  2.83it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 221it [01:10,  3.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 222it [01:10,  3.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 223it [01:10,  3.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 224it [01:10,  3.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 225it [01:11,  3.23it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 226it [01:11,  3.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 227it [01:11,  3.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 228it [01:12,  3.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 229it [01:12,  2.95it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 230it [01:13,  2.51it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 231it [01:13,  2.58it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 232it [01:13,  2.89it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 233it [01:14,  2.80it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 234it [01:14,  2.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 235it [01:14,  3.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 236it [01:15,  3.18it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 237it [01:15,  2.91it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 238it [01:15,  2.66it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 239it [01:16,  2.82it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 240it [01:16,  2.73it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 241it [01:17,  2.51it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 242it [01:17,  2.88it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 243it [01:17,  3.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 244it [01:17,  3.08it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 245it [01:18,  3.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 246it [01:18,  2.96it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 247it [01:18,  2.90it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 248it [01:19,  2.95it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 249it [01:19,  3.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 250it [01:19,  3.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 251it [01:20,  3.03it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 252it [01:20,  2.86it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 253it [01:20,  3.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 254it [01:21,  2.93it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 255it [01:21,  3.07it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 256it [01:21,  2.95it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 257it [01:22,  3.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 258it [01:22,  2.62it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 259it [01:22,  2.91it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 260it [01:23,  2.95it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 261it [01:23,  3.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 262it [01:23,  3.31it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 263it [01:24,  3.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 264it [01:24,  3.42it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 265it [01:24,  3.49it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 266it [01:25,  3.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 267it [01:25,  2.82it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 268it [01:25,  2.89it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 269it [01:26,  3.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 270it [01:26,  3.00it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 271it [01:26,  2.75it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 272it [01:27,  2.69it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 273it [01:27,  2.51it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 274it [01:28,  2.58it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 275it [01:28,  2.87it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 276it [01:28,  2.51it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 277it [01:29,  2.58it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 278it [01:29,  2.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 279it [01:29,  2.56it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 280it [01:30,  2.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 281it [01:30,  2.82it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 282it [01:30,  3.05it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# ...
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1407it [07:49,  2.85it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1408it [07:50,  2.85it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1409it [07:50,  3.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1410it [07:50,  3.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1411it [07:50,  3.50it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1412it [07:51,  2.77it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1413it [07:51,  3.00it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1414it [07:51,  3.23it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1415it [07:52,  3.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1416it [07:52,  3.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1417it [07:52,  3.03it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1418it [07:53,  3.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1419it [07:53,  3.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1420it [07:54,  2.67it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1421it [07:54,  3.06it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1422it [07:54,  3.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1423it [07:54,  3.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1424it [07:55,  3.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1425it [07:55,  3.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1426it [07:55,  3.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1427it [07:56,  2.72it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1428it [07:56,  2.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1429it [07:56,  2.77it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1430it [07:57,  2.79it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1431it [07:57,  2.79it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1432it [07:57,  3.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1433it [07:58,  3.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1434it [07:58,  3.56it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1435it [07:58,  3.06it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1436it [07:59,  3.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1437it [07:59,  3.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1438it [07:59,  3.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1439it [08:00,  2.92it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1440it [08:00,  3.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1441it [08:00,  2.97it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1442it [08:01,  1.77it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1443it [08:02,  1.98it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1444it [08:02,  2.45it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1445it [08:02,  2.76it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1446it [08:02,  3.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1447it [08:03,  3.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1448it [08:03,  3.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1449it [08:04,  2.61it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1450it [08:04,  2.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1451it [08:04,  2.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1452it [08:05,  2.84it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1453it [08:05,  3.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1454it [08:05,  3.59it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1455it [08:05,  3.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1456it [08:06,  3.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1457it [08:06,  3.61it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1458it [08:06,  3.87it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1459it [08:06,  3.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1460it [08:07,  3.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1461it [08:07,  3.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1462it [08:07,  3.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1463it [08:08,  3.18it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1464it [08:08,  2.68it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1465it [08:08,  3.06it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1466it [08:09,  2.91it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1467it [08:09,  2.84it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1468it [08:09,  3.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1469it [08:10,  3.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1470it [08:10,  3.04it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1471it [08:10,  3.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1472it [08:11,  3.08it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1473it [08:11,  3.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1474it [08:11,  3.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1475it [08:12,  2.91it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1476it [08:12,  2.97it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1477it [08:12,  3.00it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1478it [08:13,  3.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1479it [08:13,  3.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1480it [08:13,  3.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1481it [08:14,  2.91it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1482it [08:14,  2.95it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1483it [08:14,  3.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1484it [08:15,  2.87it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1485it [08:15,  2.74it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1486it [08:15,  3.03it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1487it [08:16,  3.50it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1488it [08:16,  3.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1489it [08:16,  3.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1490it [08:17,  2.93it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1491it [08:17,  2.84it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1492it [08:17,  3.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1493it [08:18,  3.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1494it [08:18,  3.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1495it [08:18,  3.11it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1496it [08:18,  3.44it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1497it [08:19,  3.58it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1498it [08:19,  3.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1499it [08:19,  3.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1500it [08:20,  3.00it/s]

# %%
name  = 'test_pred_en_2v_14_02.txt'

test_pred_en_df = []
for i in test_pred_en:
    test_pred_en_df.append('\t'.join(i))


test_pred_en_df = pd.DataFrame(test_pred_en_df)
test_pred_en_df.to_csv(name, header=None, index=None)

# %%
# !python /home/jovyan/work/debuged_task9-scorer.py /home/jovyan/work/SemEval2018-Task9/test/gold/1A.english.test.gold.txt test_pred_en_2v_14_02.txt
# Out:
# MRR: 0.4065315517815516
# MAP: 0.25253802592469293
# P@1: 0.32133333333333336
# P@3: 0.22666666666666618
# P@5: 0.22343333333333187
# P@15: 0.27160429200429154

# %%
embading_find_hyponyms_uppercase = """
MRR: 0.4065315517815516
MAP: 0.25253802592469293
P@1: 0.32133333333333336
P@3: 0.22666666666666618
P@5: 0.22343333333333187
P@15: 0.27160429200429154
find hyponyms for hyperonym: ... , target:
"""

def answers(str_ans):
    columns_name = []
    values = []
    for ind, metrics in enumerate(str_ans.split('\n')[1:-1]):
        if ind == 6:
            _name = 'prefix'
            number = metrics
        else:
            _name, number = metrics.split(' ')
            number = round(float(number), 5)
            _name = _name[:-1]
        
        columns_name.append(_name)
        values.append([number])
        
    
        
    df = pd.DataFrame(values).T
    df.columns = columns_name
    df.set_index('prefix', inplace=True)
    return df

# %%
embading_find_hyponyms_uppercase_table = answers(embading_find_hyponyms_uppercase)
embading_find_hyponyms_uppercase_table
# Out:
#                                                 MRR      MAP      P@1  \
# prefix
# find hyponyms for hyperonym: ... , target:  0.40653  0.25254  0.32133
#
#                                                 P@3      P@5    P@15
# prefix
# find hyponyms for hyperonym: ... , target:  0.22667  0.22343  0.2716

# %%
cleanup()

# %%
del trainer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[141], line 1
# ----> 1 del trainer
#
# NameError: name 'trainer' is not defined

# %%
# !nvidia-smi
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Sun Feb 26 18:30:33 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.86.01    Driver Version: 515.86.01    CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:E1:00.0 Off |                  N/A |
# |  0%   24C    P8    24W / 370W |  12791MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Embaing find hponyms for hypernym + lower case

# %%
def embading_find_hyponyms_lowercase(train_features, train_target, test_features, test_target):
    
    train_data_en = train_features.copy()
    train_data_en = 'find hyponyms for hyperonym: ' + train_data_en.term.str.lower() + ' , target:'
    print(train_data_en.head())

    train_gold_en = train_target.copy()
    train_gold_en = train_gold_en.hypernym.str.split('\t').str.join(', ').str.lower() 
    print(train_gold_en.head())
    
    test_data_en = test_features.copy()
    test_data_en = 'find hyponyms for hyperonym: ' + test_data_en.term.str.lower() + ' , target:'
    print(test_data_en.head())

    test_gold_en = test_target.copy()
    test_gold_en = test_gold_en.hypernym.str.split('\t').str.join(', ').str.lower() 
    print(test_gold_en.head())
    
    return train_data_en, train_gold_en, test_data_en, test_gold_en

# %%
train_data_en, train_gold_en, test_data_en, test_gold_en = embading_find_hyponyms_lowercase(train_data_en_data, 
                                                                                 train_gold_en_data, 
                                                                                 test_data_en_data, 
                                                                                 test_gold_en_data)
# Out:
# 0      find hyponyms for hyperonym: blackfly , target:
# 1      find hyponyms for hyperonym: turonian , target:
# 2    find hyponyms for hyperonym: abhorrence , target:
# 3    find hyponyms for hyperonym: tropical storm , ...
# 4    find hyponyms for hyperonym: militarization , ...
# Name: term, dtype: object
# 0                           homopterous insect, insect
# 1    technical specification, geologic timescale, p...
# 2                      distaste, hatred, hate, disgust
# 3    atmosphere, windstorm, violent storm, air curr...
# 4                                       social control
# Name: hypernym, dtype: object
# 0    find hyponyms for hyperonym: maliciousness , t...
# 1       find hyponyms for hyperonym: buckler , target:
# 2     find hyponyms for hyperonym: spelunker , target:
# 3    find hyponyms for hyperonym: quo warranto , ta...
# 4    find hyponyms for hyperonym: jeff francis , ta...
# Name: term, dtype: object
# 0       malevolence, distaste, hatred, hate, malignity
# 1                                           body armor
# 2                    exploration, adventurer, explorer
# 3    proceedings, legal proceedings, proceeding, du...
# 4               thrower, baseball player, jock, person
# Name: hypernym, dtype: object

# %%
train_dataset = PairsDataset(tokenizer(train_data_en.tolist()), tokenizer(train_gold_en.tolist()))
test_dataset = PairsDataset(tokenizer(test_data_en.tolist()), tokenizer(test_gold_en.tolist()))
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

args = TrainingArguments(output_dir="t5-finetuned-large", 
                         num_train_epochs=16, 
                         per_device_train_batch_size=16, save_steps=10000)

trainer = Trainer(
    model = model,
    args = args,
    train_dataset = train_dataset,
    eval_dataset = test_dataset,
    tokenizer = tokenizer,
    data_collator = data_collator
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
trainer.train()
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 1500
#   Num Epochs = 16
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1504
#   Number of trainable parameters = 737668096
#     <div>
#
#       <progress value='1504' max='1504' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1504/1504 09:19, Epoch 16/16]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.551800</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.474000</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.426900</td>
#     </tr>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=1504, training_loss=0.48421862214169603, metrics={'train_runtime': 560.0755, 'train_samples_per_second': 42.851, 'train_steps_per_second': 2.685, 'total_flos': 2195544016896000.0, 'train_loss': 0.48421862214169603, 'epoch': 16.0})

# %%
# !nvidia-smi
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Sun Feb 26 18:45:17 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.86.01    Driver Version: 515.86.01    CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:E1:00.0 Off |                  N/A |
# |  0%   32C    P8    24W / 370W |  24251MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
test_pred_en_lower = predict(test_data_en, test_gold_en)
# Out:
# 0it [00:00, ?it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# /opt/conda/lib/python3.10/site-packages/transformers/generation/beam_search.py:198: UserWarning: Passing `max_length` to BeamSearchScorer is deprecated and has no effect. `max_length` should be passed directly to `beam_search(...)`, `beam_sample(...)`, or `group_beam_search(...)`.
#   warnings.warn(
# 1it [00:00,  1.87it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 2it [00:00,  2.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 3it [00:01,  2.46it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 4it [00:01,  2.78it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 5it [00:01,  2.68it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 6it [00:02,  3.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 7it [00:02,  3.27it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 8it [00:02,  3.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 9it [00:03,  3.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 10it [00:03,  3.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 11it [00:03,  3.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 12it [00:04,  2.99it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 13it [00:04,  3.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 14it [00:04,  3.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 15it [00:05,  2.98it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 16it [00:05,  3.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 17it [00:05,  3.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 18it [00:06,  3.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 19it [00:06,  3.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 20it [00:06,  2.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 21it [00:07,  2.76it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 22it [00:07,  2.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 23it [00:08,  2.27it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 24it [00:08,  2.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 25it [00:08,  2.61it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 26it [00:09,  2.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 27it [00:09,  2.23it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 28it [00:10,  2.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 29it [00:10,  2.41it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 30it [00:11,  2.49it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 31it [00:11,  2.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 32it [00:12,  1.83it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 33it [00:12,  2.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 34it [00:13,  2.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 35it [00:13,  2.07it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 36it [00:14,  2.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 37it [00:15,  1.68it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 38it [00:15,  1.90it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 39it [00:15,  2.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 40it [00:16,  2.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 41it [00:16,  2.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 42it [00:16,  2.73it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 43it [00:17,  2.59it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 44it [00:17,  2.23it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 45it [00:18,  2.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 46it [00:18,  2.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 47it [00:19,  1.93it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 48it [00:19,  2.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 49it [00:20,  2.41it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 50it [00:20,  2.58it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 51it [00:20,  2.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 52it [00:21,  2.67it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 53it [00:21,  2.64it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 54it [00:21,  2.76it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 55it [00:22,  2.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 56it [00:22,  2.62it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 57it [00:23,  2.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 58it [00:23,  2.75it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 59it [00:24,  2.27it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 60it [00:24,  2.60it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 61it [00:24,  2.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 62it [00:25,  2.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 63it [00:25,  2.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 64it [00:25,  2.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 65it [00:26,  2.85it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 66it [00:26,  2.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 67it [00:27,  2.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 68it [00:27,  2.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 69it [00:28,  2.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 70it [00:28,  2.50it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 71it [00:28,  2.57it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 72it [00:29,  2.71it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 73it [00:29,  2.70it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 74it [00:29,  2.64it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 75it [00:30,  2.61it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 76it [00:30,  2.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 77it [00:31,  2.45it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 78it [00:31,  2.62it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 79it [00:31,  2.83it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 80it [00:32,  2.56it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 81it [00:32,  2.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 82it [00:33,  2.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 83it [00:33,  2.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 84it [00:34,  1.93it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 85it [00:34,  1.95it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 86it [00:35,  1.72it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 87it [00:36,  1.99it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 88it [00:36,  2.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 89it [00:37,  1.73it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 90it [00:37,  1.62it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 91it [00:38,  1.70it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 92it [00:38,  1.75it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 93it [00:39,  1.64it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 94it [00:40,  1.87it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 95it [00:40,  1.76it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 96it [00:41,  1.86it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 97it [00:41,  1.91it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 98it [00:42,  1.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 99it [00:43,  1.51it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 100it [00:43,  1.69it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 101it [00:44,  1.79it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 102it [00:44,  1.92it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 103it [00:45,  1.89it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 104it [00:45,  1.84it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 105it [00:46,  1.94it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 106it [00:46,  2.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 107it [00:47,  1.96it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 108it [00:47,  2.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 109it [00:47,  2.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 110it [00:48,  2.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 111it [00:48,  2.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 112it [00:48,  2.74it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 113it [00:49,  3.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 114it [00:49,  2.66it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 115it [00:50,  2.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 116it [00:50,  2.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 117it [00:51,  2.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 118it [00:51,  2.46it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 119it [00:52,  2.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 120it [00:52,  1.80it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 121it [00:53,  1.70it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 122it [00:54,  1.64it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 123it [00:54,  1.95it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 124it [00:54,  2.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 125it [00:55,  2.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 126it [00:55,  2.51it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 127it [00:55,  2.66it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 128it [00:56,  1.94it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 129it [00:56,  2.23it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 130it [00:57,  2.31it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 131it [00:57,  2.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 132it [00:58,  1.95it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 133it [00:58,  2.03it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 134it [00:59,  1.75it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 135it [01:00,  1.92it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 136it [01:00,  1.76it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 137it [01:01,  1.97it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 138it [01:01,  1.94it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 139it [01:02,  2.03it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 140it [01:02,  2.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 141it [01:02,  2.06it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 142it [01:03,  2.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 143it [01:03,  2.41it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 144it [01:03,  2.73it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 145it [01:04,  1.83it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 146it [01:05,  1.95it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 147it [01:05,  2.08it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 148it [01:06,  1.77it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 149it [01:07,  1.59it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 150it [01:08,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 151it [01:08,  1.71it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 152it [01:08,  1.97it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 153it [01:09,  2.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 154it [01:09,  2.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 155it [01:09,  2.67it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 156it [01:10,  2.41it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 157it [01:10,  2.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 158it [01:11,  2.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 159it [01:11,  2.49it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 160it [01:11,  2.64it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 161it [01:12,  2.58it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 162it [01:12,  2.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 163it [01:13,  2.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 164it [01:13,  2.07it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 165it [01:14,  2.42it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 166it [01:14,  2.56it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 167it [01:15,  2.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 168it [01:15,  2.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 169it [01:15,  2.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 170it [01:16,  2.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 171it [01:16,  2.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 172it [01:17,  2.76it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 173it [01:17,  2.85it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 174it [01:17,  2.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 175it [01:18,  2.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 176it [01:18,  2.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 177it [01:19,  2.50it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 178it [01:19,  2.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 179it [01:20,  2.23it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 180it [01:20,  2.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 181it [01:20,  2.60it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 182it [01:21,  2.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 183it [01:21,  2.58it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 184it [01:22,  2.42it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 185it [01:22,  2.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 186it [01:23,  1.87it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 187it [01:23,  1.88it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 188it [01:24,  2.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 189it [01:24,  2.08it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 190it [01:24,  2.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 191it [01:25,  2.71it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 192it [01:25,  2.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 193it [01:26,  2.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 194it [01:26,  2.71it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 195it [01:26,  2.18it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 196it [01:27,  2.06it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 197it [01:27,  2.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 198it [01:28,  2.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 199it [01:28,  2.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 200it [01:29,  2.06it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 201it [01:29,  2.41it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 202it [01:29,  2.58it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 203it [01:30,  2.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 204it [01:30,  2.46it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 205it [01:31,  2.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 206it [01:31,  2.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 207it [01:32,  2.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 208it [01:32,  2.58it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 209it [01:32,  2.57it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 210it [01:32,  2.87it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 211it [01:33,  2.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 212it [01:34,  2.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 213it [01:34,  1.97it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 214it [01:35,  2.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 215it [01:35,  2.31it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 216it [01:36,  1.75it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 217it [01:36,  1.85it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 218it [01:37,  2.03it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 219it [01:37,  2.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 220it [01:38,  1.71it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 221it [01:38,  2.06it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 222it [01:39,  2.04it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 223it [01:39,  1.90it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 224it [01:40,  1.93it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 225it [01:40,  2.18it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 226it [01:41,  2.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 227it [01:41,  2.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 228it [01:41,  2.41it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 229it [01:42,  2.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 230it [01:42,  2.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 231it [01:43,  2.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 232it [01:43,  2.08it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 233it [01:44,  2.31it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 234it [01:44,  2.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 235it [01:44,  2.83it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 236it [01:45,  2.72it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 237it [01:45,  2.31it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 238it [01:46,  2.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 239it [01:46,  2.46it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 240it [01:46,  2.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 241it [01:47,  2.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 242it [01:47,  2.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 243it [01:48,  2.41it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 244it [01:48,  2.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 245it [01:49,  2.42it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 246it [01:49,  2.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 247it [01:49,  2.46it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 248it [01:50,  2.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 249it [01:50,  2.42it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 250it [01:51,  2.82it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 251it [01:51,  2.99it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 252it [01:51,  2.66it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 253it [01:52,  2.42it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 254it [01:52,  2.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 255it [01:53,  2.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 256it [01:53,  2.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 257it [01:53,  2.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 258it [01:54,  2.03it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 259it [01:55,  2.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 260it [01:55,  1.71it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 261it [01:56,  1.88it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 262it [01:56,  1.99it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 263it [01:57,  2.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 264it [01:57,  2.49it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 265it [01:57,  2.89it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 266it [01:58,  2.66it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 267it [01:58,  2.23it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 268it [01:59,  2.31it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 269it [01:59,  2.46it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 270it [01:59,  2.31it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 271it [02:00,  2.64it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 272it [02:00,  2.81it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 273it [02:01,  2.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 274it [02:01,  1.93it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 275it [02:02,  1.97it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 276it [02:02,  1.90it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 277it [02:03,  1.57it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 278it [02:04,  1.60it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 279it [02:05,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 280it [02:06,  1.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# ...
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1407it [10:57,  2.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1408it [10:57,  2.61it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1409it [10:58,  2.66it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1410it [10:58,  2.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1411it [10:59,  2.06it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1412it [10:59,  2.06it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1413it [11:00,  2.51it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1414it [11:00,  2.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1415it [11:01,  2.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1416it [11:01,  2.31it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1417it [11:02,  1.86it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1418it [11:02,  2.18it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1419it [11:02,  2.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1420it [11:04,  1.58it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1421it [11:04,  1.75it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1422it [11:05,  1.66it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1423it [11:06,  1.42it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1424it [11:06,  1.60it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1425it [11:06,  1.84it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1426it [11:07,  2.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1427it [11:07,  2.06it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1428it [11:08,  1.88it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1429it [11:08,  2.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1430it [11:09,  2.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1431it [11:09,  2.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1432it [11:09,  2.23it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1433it [11:10,  2.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1434it [11:10,  2.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1435it [11:11,  2.08it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1436it [11:11,  2.03it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1437it [11:12,  2.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1438it [11:12,  2.03it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1439it [11:13,  2.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1440it [11:13,  2.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1441it [11:14,  2.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1442it [11:15,  1.72it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1443it [11:15,  1.80it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1444it [11:15,  1.96it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1445it [11:16,  2.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1446it [11:16,  2.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1447it [11:17,  2.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1448it [11:17,  1.93it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1449it [11:18,  1.86it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1450it [11:19,  1.44it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1451it [11:20,  1.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1452it [11:20,  1.80it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1453it [11:20,  2.05it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1454it [11:20,  2.46it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1455it [11:21,  2.60it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1456it [11:21,  2.81it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1457it [11:21,  2.89it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1458it [11:22,  2.85it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1459it [11:22,  2.88it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1460it [11:22,  2.84it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1461it [11:23,  2.66it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1462it [11:23,  2.51it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1463it [11:24,  2.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1464it [11:25,  1.90it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1465it [11:25,  2.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1466it [11:26,  1.91it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1467it [11:26,  1.93it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1468it [11:26,  2.07it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1469it [11:27,  2.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1470it [11:27,  1.99it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1471it [11:28,  2.08it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1472it [11:28,  1.95it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1473it [11:29,  2.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1474it [11:29,  2.41it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1475it [11:30,  2.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1476it [11:30,  2.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1477it [11:31,  2.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1478it [11:31,  2.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1479it [11:31,  2.62it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1480it [11:32,  2.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1481it [11:32,  2.70it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1482it [11:32,  2.69it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1483it [11:33,  2.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1484it [11:34,  1.50it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1485it [11:35,  1.64it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1486it [11:35,  1.86it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1487it [11:35,  2.06it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1488it [11:36,  1.98it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1489it [11:36,  1.97it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1490it [11:37,  2.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1491it [11:37,  2.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1492it [11:37,  2.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1493it [11:38,  2.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1494it [11:38,  2.61it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1495it [11:39,  2.46it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1496it [11:39,  2.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1497it [11:39,  2.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1498it [11:40,  2.50it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1499it [11:40,  2.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1500it [11:41,  2.14it/s]

# %%
name  = 'test_pred_en_lower.txt'

test_pred_en_df = []
for i in test_pred_en_lower:
    test_pred_en_df.append('\t'.join(i))


test_pred_en_df = pd.DataFrame(test_pred_en_df)
test_pred_en_df.to_csv(name, header=None, index=None)

# %%
# !python /home/jovyan/work/debuged_task9-scorer.py /home/jovyan/work/SemEval2018-Task9/test/gold/1A.english.test.gold.txt test_pred_en_lower.txt
# Out:
# MRR: 0.38439761534761535
# MAP: 0.24742700657367342
# P@1: 0.298
# P@3: 0.21433333333333338
# P@5: 0.21696666666666548
# P@15: 0.27681979686979663

# %%
embading_find_hyponyms_lowercase = """
MRR: 0.38439761534761535
MAP: 0.24742700657367342
P@1: 0.298
P@3: 0.21433333333333338
P@5: 0.21696666666666548
P@15: 0.27681979686979663
find hyponyms for hyperonym: ..., target: + all words lowercase'
""" 


embading_find_hyponyms_lowercase_table = answers(embading_find_hyponyms_lowercase)
embading_find_hyponyms_lowercase_table
# Out:
#                                                        MRR      MAP    P@1  \
# prefix
# find hyponyms for hyperonym: ..., target: + all...  0.3844  0.24743  0.298
#
#                                                         P@3      P@5     P@15
# prefix
# find hyponyms for hyperonym: ..., target: + all...  0.21433  0.21697  0.27682

# %%
# !nvidia-smi
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Sun Feb 26 19:00:18 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.86.01    Driver Version: 515.86.01    CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:E1:00.0 Off |                  N/A |
# |  0%   24C    P8    25W / 370W |  24251MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
cleanup()
del trainer

# %%
# !nvidia-smi
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Sun Feb 26 19:00:38 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.86.01    Driver Version: 515.86.01    CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:E1:00.0 Off |                  N/A |
# |  0%   28C    P3   133W / 370W |  12925MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Standard emabdding

# %%
def standard_preprocessing(train_features, train_target, test_features, test_target):
    
    train_data_en = train_features.copy()
    train_data_en = 'hyperonym: ' + train_data_en.term + ' | hyponyms:'
    print(train_data_en.head())

    train_gold_en = train_target.copy()
    train_gold_en = train_gold_en.hypernym.str.split('\t').str.join(', ')
    print(train_gold_en.head())
    
    test_data_en = test_features.copy()
    test_data_en = 'hyperonym: ' + test_data_en.term + ' | hyponyms:'
    print(test_data_en.head())

    test_gold_en = test_target.copy()
    test_gold_en = test_gold_en.hypernym.str.split('\t').str.join(', ')
    print(test_gold_en.head())
    
    return train_data_en, train_gold_en, test_data_en, test_gold_en

train_data_en, train_gold_en, test_data_en, test_gold_en = standard_preprocessing(train_data_en_data, 
                                                                                 train_gold_en_data, 
                                                                                 test_data_en_data, 
                                                                                 test_gold_en_data)
# Out:
# 0          hyperonym: blackfly | hyponyms:
# 1          hyperonym: Turonian | hyponyms:
# 2        hyperonym: abhorrence | hyponyms:
# 3    hyperonym: tropical storm | hyponyms:
# 4    hyperonym: militarization | hyponyms:
# Name: term, dtype: object
# 0                           homopterous insect, insect
# 1    technical specification, geologic timescale, p...
# 2                      distaste, hatred, hate, disgust
# 3    atmosphere, windstorm, violent storm, air curr...
# 4                                       social control
# Name: hypernym, dtype: object
# 0    hyperonym: maliciousness | hyponyms:
# 1          hyperonym: buckler | hyponyms:
# 2        hyperonym: spelunker | hyponyms:
# 3     hyperonym: quo warranto | hyponyms:
# 4     hyperonym: Jeff Francis | hyponyms:
# Name: term, dtype: object
# 0       malevolence, distaste, hatred, hate, malignity
# 1                                           body armor
# 2                    exploration, adventurer, explorer
# 3    proceedings, legal proceedings, proceeding, du...
# 4               thrower, baseball player, jock, person
# Name: hypernym, dtype: object

# %%
train_dataset = PairsDataset(tokenizer(train_data_en.tolist()), tokenizer(train_gold_en.tolist()))
test_dataset = PairsDataset(tokenizer(test_data_en.tolist()), tokenizer(test_gold_en.tolist()))
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

args = TrainingArguments(output_dir="t5-finetuned-large", 
                         num_train_epochs=16, 
                         per_device_train_batch_size=16, save_steps=10000)

trainer = Trainer(
    model = model,
    args = args,
    train_dataset = train_dataset,
    eval_dataset = test_dataset,
    tokenizer = tokenizer,
    data_collator = data_collator
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
trainer.train()
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 1500
#   Num Epochs = 16
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1504
#   Number of trainable parameters = 737668096
#     <div>
#
#       <progress value='1504' max='1504' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1504/1504 09:07, Epoch 16/16]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.304900</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.252900</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.220600</td>
#     </tr>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=1504, training_loss=0.2594152844332634, metrics={'train_runtime': 547.8558, 'train_samples_per_second': 43.807, 'train_steps_per_second': 2.745, 'total_flos': 1646941329408000.0, 'train_loss': 0.2594152844332634, 'epoch': 16.0})

# %%
test_pred_en_standard = predict(test_data_en, test_gold_en)
# Out:
# 0it [00:00, ?it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# /opt/conda/lib/python3.10/site-packages/transformers/generation/beam_search.py:198: UserWarning: Passing `max_length` to BeamSearchScorer is deprecated and has no effect. `max_length` should be passed directly to `beam_search(...)`, `beam_sample(...)`, or `group_beam_search(...)`.
#   warnings.warn(
# 1it [00:00,  1.23it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 2it [00:01,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 3it [00:02,  1.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 4it [00:02,  1.72it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 5it [00:03,  1.74it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 6it [00:03,  2.03it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 7it [00:03,  2.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 8it [00:04,  2.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 9it [00:04,  2.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 10it [00:05,  1.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 11it [00:06,  1.58it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 12it [00:07,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 13it [00:08,  1.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 14it [00:09,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 15it [00:09,  1.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 16it [00:10,  1.44it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 17it [00:10,  1.44it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 18it [00:11,  1.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 19it [00:12,  1.51it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 20it [00:12,  1.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 21it [00:13,  1.62it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 22it [00:14,  1.35it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 23it [00:15,  1.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 24it [00:16,  1.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 25it [00:17,  1.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 26it [00:17,  1.18it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 27it [00:18,  1.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 28it [00:20,  1.09s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 29it [00:20,  1.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 30it [00:21,  1.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 31it [00:23,  1.28s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 32it [00:25,  1.40s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 33it [00:26,  1.34s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 34it [00:27,  1.24s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 35it [00:28,  1.17s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 36it [00:29,  1.03it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 37it [00:30,  1.16s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 38it [00:31,  1.01s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 39it [00:32,  1.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 40it [00:32,  1.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 41it [00:33,  1.27it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 42it [00:34,  1.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 43it [00:34,  1.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 44it [00:35,  1.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 45it [00:36,  1.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 46it [00:37,  1.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 47it [00:38,  1.31it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 48it [00:38,  1.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 49it [00:39,  1.63it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 50it [00:39,  1.60it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 51it [00:40,  1.50it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 52it [00:41,  1.59it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 53it [00:41,  1.78it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 54it [00:41,  1.88it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 55it [00:42,  1.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 56it [00:43,  1.72it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 57it [00:43,  1.94it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 58it [00:44,  2.04it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 59it [00:44,  2.07it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 60it [00:44,  2.35it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 61it [00:45,  1.86it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 62it [00:46,  2.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 63it [00:47,  1.49it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 64it [00:47,  1.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 65it [00:48,  1.73it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 66it [00:49,  1.44it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 67it [00:49,  1.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 68it [00:51,  1.01s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 69it [00:52,  1.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 70it [00:52,  1.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 71it [00:53,  1.31it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 72it [00:53,  1.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 73it [00:54,  1.67it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 74it [00:55,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 75it [00:56,  1.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 76it [00:57,  1.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 77it [00:58,  1.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 78it [00:58,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 79it [00:59,  1.61it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 80it [01:00,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 81it [01:01,  1.08it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 82it [01:02,  1.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 83it [01:03,  1.18it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 84it [01:04,  1.03s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 85it [01:05,  1.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 86it [01:06,  1.05s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 87it [01:07,  1.07s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 88it [01:08,  1.05it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 89it [01:09,  1.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 90it [01:09,  1.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 91it [01:10,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 92it [01:11,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 93it [01:11,  1.45it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 94it [01:12,  1.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 95it [01:13,  1.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 96it [01:13,  1.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 97it [01:14,  1.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 98it [01:15,  1.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 99it [01:16,  1.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 100it [01:17,  1.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 101it [01:17,  1.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 102it [01:18,  1.78it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 103it [01:18,  1.83it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 104it [01:20,  1.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 105it [01:20,  1.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 106it [01:21,  1.35it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 107it [01:22,  1.08it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 108it [01:23,  1.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 109it [01:23,  1.41it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 110it [01:25,  1.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 111it [01:25,  1.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 112it [01:26,  1.44it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 113it [01:26,  1.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 114it [01:27,  1.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 115it [01:29,  1.06s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 116it [01:30,  1.00it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 117it [01:30,  1.11it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 118it [01:31,  1.11it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 119it [01:32,  1.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 120it [01:33,  1.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 121it [01:33,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 122it [01:34,  1.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 123it [01:35,  1.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 124it [01:36,  1.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 125it [01:37,  1.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 126it [01:38,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 127it [01:38,  1.46it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 128it [01:39,  1.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 129it [01:40,  1.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 130it [01:41,  1.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 131it [01:41,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 132it [01:43,  1.03s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 133it [01:44,  1.01s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 134it [01:45,  1.15s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 135it [01:46,  1.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 136it [01:47,  1.08it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 137it [01:48,  1.03s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 138it [01:49,  1.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 139it [01:49,  1.31it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 140it [01:50,  1.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 141it [01:51,  1.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 142it [01:51,  1.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 143it [01:52,  1.56it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 144it [01:52,  1.66it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 145it [01:53,  1.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 146it [01:54,  1.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 147it [01:55,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 148it [01:56,  1.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 149it [01:57,  1.02s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 150it [01:59,  1.15s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 151it [01:59,  1.03it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 152it [02:00,  1.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 153it [02:01,  1.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 154it [02:02,  1.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 155it [02:02,  1.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 156it [02:03,  1.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 157it [02:04,  1.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 158it [02:05,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 159it [02:05,  1.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 160it [02:07,  1.08s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 161it [02:08,  1.13s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 162it [02:09,  1.03s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 163it [02:10,  1.06it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 164it [02:10,  1.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 165it [02:11,  1.51it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 166it [02:11,  1.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 167it [02:12,  1.44it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 168it [02:13,  1.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 169it [02:14,  1.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 170it [02:15,  1.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 171it [02:16,  1.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 172it [02:16,  1.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 173it [02:17,  1.50it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 174it [02:17,  1.58it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 175it [02:18,  1.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 176it [02:19,  1.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 177it [02:20,  1.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 178it [02:21,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 179it [02:21,  1.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 180it [02:22,  1.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 181it [02:23,  1.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 182it [02:23,  1.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 183it [02:24,  1.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 184it [02:25,  1.44it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 185it [02:26,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 186it [02:26,  1.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 187it [02:27,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 188it [02:28,  1.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 189it [02:29,  1.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 190it [02:29,  1.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 191it [02:30,  1.74it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 192it [02:30,  1.56it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 193it [02:31,  1.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 194it [02:31,  1.76it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 195it [02:33,  1.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 196it [02:34,  1.23it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 197it [02:34,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 198it [02:35,  1.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 199it [02:36,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 200it [02:36,  1.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 201it [02:37,  1.80it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 202it [02:37,  1.97it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 203it [02:37,  2.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 204it [02:38,  2.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 205it [02:38,  1.93it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 206it [02:39,  1.79it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 207it [02:40,  1.96it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 208it [02:40,  1.76it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 209it [02:41,  1.82it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 210it [02:41,  2.08it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 211it [02:41,  2.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 212it [02:42,  1.98it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 213it [02:43,  1.57it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 214it [02:43,  1.77it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 215it [02:44,  1.87it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 216it [02:45,  1.72it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 217it [02:45,  1.87it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 218it [02:46,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 219it [02:48,  1.12s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 220it [02:49,  1.13s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 221it [02:50,  1.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 222it [02:50,  1.31it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 223it [02:52,  1.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 224it [02:52,  1.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 225it [02:53,  1.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 226it [02:54,  1.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 227it [02:55,  1.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 228it [02:55,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 229it [02:56,  1.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 230it [02:57,  1.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 231it [02:58,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 232it [02:58,  1.49it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 233it [02:58,  1.76it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 234it [02:59,  1.94it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 235it [02:59,  2.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 236it [03:00,  2.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 237it [03:00,  1.78it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 238it [03:01,  1.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 239it [03:02,  1.72it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 240it [03:02,  1.60it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 241it [03:03,  1.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 242it [03:04,  1.66it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 243it [03:04,  1.50it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 244it [03:05,  1.44it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 245it [03:05,  1.72it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 246it [03:07,  1.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 247it [03:08,  1.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 248it [03:08,  1.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 249it [03:09,  1.42it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 250it [03:09,  1.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 251it [03:10,  1.75it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 252it [03:11,  1.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 253it [03:11,  1.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 254it [03:13,  1.04it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 255it [03:13,  1.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 256it [03:14,  1.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 257it [03:15,  1.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 258it [03:16,  1.04it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 259it [03:17,  1.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 260it [03:18,  1.01s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 261it [03:19,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 262it [03:19,  1.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 263it [03:19,  1.68it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 264it [03:20,  1.83it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 265it [03:20,  2.18it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 266it [03:20,  2.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 267it [03:22,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 268it [03:23,  1.23it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 269it [03:23,  1.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 270it [03:24,  1.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 271it [03:25,  1.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 272it [03:26,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 273it [03:27,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 274it [03:28,  1.04it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 275it [03:29,  1.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 276it [03:30,  1.05it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 277it [03:31,  1.17s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 278it [03:34,  1.44s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 279it [03:35,  1.36s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 280it [03:36,  1.21s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# ...
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1407it [17:35,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1408it [17:35,  1.42it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1409it [17:36,  1.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1410it [17:36,  1.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1411it [17:37,  1.41it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1412it [17:38,  1.49it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1413it [17:38,  1.74it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1414it [17:39,  1.66it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1415it [17:40,  1.06it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1416it [17:42,  1.13s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1417it [17:44,  1.29s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1418it [17:44,  1.07s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1419it [17:45,  1.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1420it [17:46,  1.00s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1421it [17:46,  1.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1422it [17:47,  1.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1423it [17:48,  1.27it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1424it [17:48,  1.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1425it [17:49,  1.50it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1426it [17:49,  1.76it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1427it [17:50,  1.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1428it [17:51,  1.45it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1429it [17:51,  1.51it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1430it [17:52,  1.68it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1431it [17:52,  1.69it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1432it [17:53,  1.74it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1433it [17:54,  1.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1434it [17:55,  1.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1435it [17:56,  1.27it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1436it [17:57,  1.27it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1437it [17:58,  1.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1438it [17:59,  1.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1439it [17:59,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1440it [18:00,  1.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1441it [18:01,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1442it [18:02,  1.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1443it [18:03,  1.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1444it [18:03,  1.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1445it [18:04,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1446it [18:05,  1.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1447it [18:06,  1.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1448it [18:07,  1.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1449it [18:08,  1.04it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1450it [18:09,  1.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1451it [18:10,  1.18it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1452it [18:10,  1.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1453it [18:11,  1.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1454it [18:11,  1.58it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1455it [18:12,  1.69it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1456it [18:12,  1.91it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1457it [18:13,  2.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1458it [18:13,  2.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1459it [18:14,  2.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1460it [18:15,  1.51it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1461it [18:15,  1.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1462it [18:16,  1.60it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1463it [18:16,  1.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1464it [18:17,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1465it [18:18,  1.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1466it [18:19,  1.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1467it [18:20,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1468it [18:21,  1.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1469it [18:21,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1470it [18:22,  1.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1471it [18:23,  1.06it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1472it [18:24,  1.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1473it [18:25,  1.31it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1474it [18:25,  1.49it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1475it [18:26,  1.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1476it [18:27,  1.06it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1477it [18:28,  1.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1478it [18:28,  1.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1479it [18:29,  1.71it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1480it [18:29,  1.75it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1481it [18:30,  1.70it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1482it [18:30,  1.75it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1483it [18:31,  1.88it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1484it [18:32,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1485it [18:32,  1.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1486it [18:33,  1.79it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1487it [18:33,  2.05it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1488it [18:34,  1.84it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1489it [18:34,  1.71it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1490it [18:35,  1.74it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1491it [18:36,  1.59it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1492it [18:36,  1.87it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1493it [18:36,  2.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1494it [18:37,  1.80it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1495it [18:38,  1.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1496it [18:39,  1.35it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1497it [18:40,  1.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1498it [18:41,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1499it [18:41,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1500it [18:42,  1.34it/s]

# %%
name  = 'test_pred_en_standard.txt'

test_pred_en_df = []
for i in test_pred_en_standard:
    test_pred_en_df.append('\t'.join(i))


test_pred_en_df = pd.DataFrame(test_pred_en_df)
test_pred_en_df.to_csv(name, header=None, index=None)

# %%
# !python /home/jovyan/work/debuged_task9-scorer.py /home/jovyan/work/SemEval2018-Task9/test/gold/1A.english.test.gold.txt test_pred_en_standard.txt
# Out:
# MRR: 0.36780024420024393
# MAP: 0.2419887540854206
# P@1: 0.2846666666666667
# P@3: 0.20277777777777792
# P@5: 0.20804444444444353
# P@15: 0.2814029766529765

# %%
embading_standard = """
MRR: 0.36780024420024393
MAP: 0.2419887540854206
P@1: 0.2846666666666667
P@3: 0.20277777777777792
P@5: 0.20804444444444353
P@15: 0.2814029766529765
hyperonym: ... | hyponyms:
""" 


embading_standard_table = answers(embading_standard)
embading_standard_table
# Out:
#                                MRR      MAP      P@1      P@3      P@5    P@15
# prefix
# hyperonym: ... | hyponyms:  0.3678  0.24199  0.28467  0.20278  0.20804  0.2814

# %%
cleanup()
del trainer

# %%
# !nvidia-smi
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Sun Feb 26 20:02:54 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.86.01    Driver Version: 515.86.01    CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:E1:00.0 Off |                  N/A |
# |  0%   33C    P2   125W / 370W |  12925MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Embadding with term

# %%
def emadding_with_term_and_find_prefix(train_features, train_target, test_features, test_target):
    
    train_data_en = train_features.copy()
    train_data_en = 'find hyponyms for hyperonym ' + train_data_en.term + \
    ' with relationship ' + train_data_en.relation.str.lower() + ' , target:'
    print(train_data_en.head())

    train_gold_en = train_target.copy()
    train_gold_en = train_gold_en.hypernym.str.split('\t').str.join(', ')
    print(train_gold_en.head())
    
    test_data_en = test_features.copy()
    test_data_en = 'find hyponyms for hyperonym ' + test_data_en.term + \
    ' with relationship ' + test_data_en.relation.str.lower() + ' , target:'
    print(test_data_en.head())

    test_gold_en = test_target.copy()
    test_gold_en = test_gold_en.hypernym.str.split('\t').str.join(', ')
    print(test_gold_en.head())
    
    return train_data_en, train_gold_en, test_data_en, test_gold_en

train_data_en, train_gold_en, test_data_en, test_gold_en = emadding_with_term_and_find_prefix(train_data_en_data, 
                                                                                 train_gold_en_data, 
                                                                                 test_data_en_data, 
                                                                                 test_gold_en_data)
# Out:
# 0    find hyponyms for hyperonym blackfly with rela...
# 1    find hyponyms for hyperonym Turonian with rela...
# 2    find hyponyms for hyperonym abhorrence with re...
# 3    find hyponyms for hyperonym tropical storm wit...
# 4    find hyponyms for hyperonym militarization wit...
# dtype: object
# 0                           homopterous insect, insect
# 1    technical specification, geologic timescale, p...
# 2                      distaste, hatred, hate, disgust
# 3    atmosphere, windstorm, violent storm, air curr...
# 4                                       social control
# Name: hypernym, dtype: object
# 0    find hyponyms for hyperonym maliciousness with...
# 1    find hyponyms for hyperonym buckler with relat...
# 2    find hyponyms for hyperonym spelunker with rel...
# 3    find hyponyms for hyperonym quo warranto with ...
# 4    find hyponyms for hyperonym Jeff Francis with ...
# dtype: object
# 0       malevolence, distaste, hatred, hate, malignity
# 1                                           body armor
# 2                    exploration, adventurer, explorer
# 3    proceedings, legal proceedings, proceeding, du...
# 4               thrower, baseball player, jock, person
# Name: hypernym, dtype: object

# %%
train_dataset = PairsDataset(tokenizer(train_data_en.tolist()), tokenizer(train_gold_en.tolist()))
test_dataset = PairsDataset(tokenizer(test_data_en.tolist()), tokenizer(test_gold_en.tolist()))
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

args = TrainingArguments(output_dir="t5-finetuned-large", 
                         num_train_epochs=16, 
                         per_device_train_batch_size=16, save_steps=10000)

trainer = Trainer(
    model = model,
    args = args,
    train_dataset = train_dataset,
    eval_dataset = test_dataset,
    tokenizer = tokenizer,
    data_collator = data_collator
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
trainer.train()
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 1500
#   Num Epochs = 16
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1504
#   Number of trainable parameters = 737668096
#     <div>
#
#       <progress value='1504' max='1504' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1504/1504 09:25, Epoch 16/16]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.217700</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.172700</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.145900</td>
#     </tr>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=1504, training_loss=0.17872325755021673, metrics={'train_runtime': 565.7534, 'train_samples_per_second': 42.421, 'train_steps_per_second': 2.658, 'total_flos': 2255860881408000.0, 'train_loss': 0.17872325755021673, 'epoch': 16.0})

# %%
test_pred_en_with_term_find = predict(test_data_en, test_gold_en)
# Out:
# 0it [00:00, ?it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# /opt/conda/lib/python3.10/site-packages/transformers/generation/beam_search.py:198: UserWarning: Passing `max_length` to BeamSearchScorer is deprecated and has no effect. `max_length` should be passed directly to `beam_search(...)`, `beam_sample(...)`, or `group_beam_search(...)`.
#   warnings.warn(
# 1it [00:00,  1.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 2it [00:01,  1.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 3it [00:02,  1.11it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 4it [00:03,  1.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 5it [00:04,  1.27it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 6it [00:04,  1.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 7it [00:04,  1.90it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 8it [00:05,  2.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 9it [00:05,  1.86it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 10it [00:06,  1.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 11it [00:07,  1.66it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 12it [00:08,  1.44it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 13it [00:09,  1.23it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 14it [00:10,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 15it [00:10,  1.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 16it [00:11,  1.51it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 17it [00:11,  1.45it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 18it [00:12,  1.42it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 19it [00:13,  1.59it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 20it [00:13,  1.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 21it [00:14,  1.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 22it [00:15,  1.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 23it [00:16,  1.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 24it [00:17,  1.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 25it [00:19,  1.19s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 26it [00:20,  1.06s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 27it [00:20,  1.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 28it [00:22,  1.01s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 29it [00:22,  1.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 30it [00:23,  1.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 31it [00:25,  1.09s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 32it [00:26,  1.08s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 33it [00:26,  1.07it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 34it [00:27,  1.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 35it [00:28,  1.01s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 36it [00:29,  1.11it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 37it [00:31,  1.25s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 38it [00:32,  1.03s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 39it [00:33,  1.08s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 40it [00:33,  1.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 41it [00:34,  1.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 42it [00:34,  1.46it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 43it [00:35,  1.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 44it [00:36,  1.41it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 45it [00:36,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 46it [00:37,  1.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 47it [00:38,  1.35it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 48it [00:39,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 49it [00:39,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 50it [00:40,  1.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 51it [00:41,  1.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 52it [00:42,  1.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 53it [00:42,  1.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 54it [00:43,  1.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 55it [00:44,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 56it [00:44,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 57it [00:45,  1.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 58it [00:47,  1.05it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 59it [00:48,  1.04it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 60it [00:48,  1.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 61it [00:50,  1.03it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 62it [00:50,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 63it [00:51,  1.11it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 64it [00:52,  1.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 65it [00:52,  1.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 66it [00:53,  1.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 67it [00:54,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 68it [00:56,  1.35s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 69it [00:57,  1.07s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 70it [00:58,  1.02s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 71it [00:58,  1.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 72it [00:59,  1.35it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 73it [00:59,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 74it [01:02,  1.18s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 75it [01:03,  1.13s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 76it [01:04,  1.06s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 77it [01:04,  1.00it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 78it [01:05,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 79it [01:05,  1.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 80it [01:06,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 81it [01:07,  1.06it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 82it [01:09,  1.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 83it [01:09,  1.08it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 84it [01:11,  1.23s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 85it [01:12,  1.24s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 86it [01:14,  1.27s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 87it [01:15,  1.23s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 88it [01:16,  1.15s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 89it [01:17,  1.25s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 90it [01:18,  1.10s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 91it [01:19,  1.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 92it [01:19,  1.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 93it [01:20,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 94it [01:21,  1.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 95it [01:22,  1.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 96it [01:22,  1.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 97it [01:24,  1.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 98it [01:25,  1.10s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 99it [01:26,  1.07s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 100it [01:27,  1.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 101it [01:27,  1.41it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 102it [01:28,  1.49it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 103it [01:28,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 104it [01:30,  1.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 105it [01:30,  1.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 106it [01:31,  1.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 107it [01:32,  1.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 108it [01:32,  1.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 109it [01:33,  1.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 110it [01:35,  1.05it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 111it [01:35,  1.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 112it [01:36,  1.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 113it [01:36,  1.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 114it [01:37,  1.50it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 115it [01:38,  1.23it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 116it [01:39,  1.00s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 117it [01:40,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 118it [01:41,  1.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 119it [01:42,  1.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 120it [01:42,  1.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 121it [01:43,  1.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 122it [01:44,  1.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 123it [01:44,  1.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 124it [01:45,  1.35it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 125it [01:46,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 126it [01:46,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 127it [01:47,  1.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 128it [01:48,  1.51it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 129it [01:48,  1.68it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 130it [01:49,  1.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 131it [01:50,  1.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 132it [01:50,  1.41it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 133it [01:51,  1.44it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 134it [01:52,  1.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 135it [01:53,  1.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 136it [01:54,  1.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 137it [01:55,  1.03s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 138it [01:56,  1.05it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 139it [01:57,  1.11it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 140it [01:57,  1.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 141it [01:59,  1.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 142it [01:59,  1.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 143it [02:00,  1.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 144it [02:00,  1.49it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 145it [02:02,  1.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 146it [02:02,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 147it [02:03,  1.35it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 148it [02:04,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 149it [02:05,  1.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 150it [02:07,  1.18s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 151it [02:07,  1.06it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 152it [02:08,  1.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 153it [02:09,  1.01s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 154it [02:10,  1.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 155it [02:10,  1.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 156it [02:11,  1.31it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 157it [02:12,  1.42it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 158it [02:12,  1.59it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 159it [02:13,  1.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 160it [02:13,  1.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 161it [02:14,  1.35it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 162it [02:15,  1.27it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 163it [02:16,  1.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 164it [02:17,  1.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 165it [02:17,  1.35it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 166it [02:18,  1.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 167it [02:19,  1.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 168it [02:21,  1.01s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 169it [02:22,  1.08s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 170it [02:23,  1.20s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 171it [02:24,  1.11s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 172it [02:24,  1.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 173it [02:25,  1.23it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 174it [02:26,  1.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 175it [02:26,  1.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 176it [02:27,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 177it [02:28,  1.35it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 178it [02:29,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 179it [02:29,  1.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 180it [02:30,  1.35it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 181it [02:31,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 182it [02:32,  1.45it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 183it [02:32,  1.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 184it [02:33,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 185it [02:34,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 186it [02:34,  1.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 187it [02:35,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 188it [02:36,  1.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 189it [02:37,  1.46it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 190it [02:37,  1.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 191it [02:38,  1.61it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 192it [02:39,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 193it [02:39,  1.50it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 194it [02:40,  1.60it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 195it [02:41,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 196it [02:41,  1.42it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 197it [02:42,  1.66it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 198it [02:43,  1.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 199it [02:43,  1.63it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 200it [02:44,  1.57it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 201it [02:44,  1.77it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 202it [02:45,  1.99it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 203it [02:45,  1.76it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 204it [02:46,  1.62it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 205it [02:47,  1.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 206it [02:47,  1.42it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 207it [02:48,  1.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 208it [02:49,  1.60it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 209it [02:49,  1.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 210it [02:50,  1.73it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 211it [02:51,  1.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 212it [02:52,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 213it [02:53,  1.04it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 214it [02:53,  1.23it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 215it [02:54,  1.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 216it [02:55,  1.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 217it [02:56,  1.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 218it [02:57,  1.23it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 219it [02:58,  1.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 220it [02:59,  1.04s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 221it [03:00,  1.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 222it [03:00,  1.18it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 223it [03:02,  1.04it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 224it [03:03,  1.08it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 225it [03:03,  1.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 226it [03:04,  1.06it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 227it [03:05,  1.01s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 228it [03:06,  1.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 229it [03:07,  1.08it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 230it [03:08,  1.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 231it [03:10,  1.15s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 232it [03:10,  1.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 233it [03:11,  1.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 234it [03:12,  1.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 235it [03:12,  1.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 236it [03:13,  1.41it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 237it [03:14,  1.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 238it [03:15,  1.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 239it [03:16,  1.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 240it [03:17,  1.00s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 241it [03:18,  1.03it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 242it [03:18,  1.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 243it [03:19,  1.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 244it [03:20,  1.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 245it [03:20,  1.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 246it [03:22,  1.06it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 247it [03:23,  1.06s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 248it [03:24,  1.03s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 249it [03:25,  1.00it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 250it [03:26,  1.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 251it [03:26,  1.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 252it [03:27,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 253it [03:28,  1.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 254it [03:29,  1.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 255it [03:30,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 256it [03:31,  1.07it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 257it [03:31,  1.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 258it [03:33,  1.09s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 259it [03:34,  1.03it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 260it [03:36,  1.23s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 261it [03:37,  1.20s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 262it [03:38,  1.17s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 263it [03:38,  1.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 264it [03:39,  1.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 265it [03:39,  1.41it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 266it [03:40,  1.49it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 267it [03:41,  1.06it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 268it [03:42,  1.07it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 269it [03:43,  1.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 270it [03:44,  1.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 271it [03:44,  1.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 272it [03:45,  1.63it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 273it [03:46,  1.27it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 274it [03:47,  1.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 275it [03:48,  1.04s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 276it [03:50,  1.12s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 277it [03:52,  1.35s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 278it [03:54,  1.62s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 279it [03:55,  1.58s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 280it [03:56,  1.38s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# ...
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1407it [19:29,  1.05it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1408it [19:29,  1.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1409it [19:30,  1.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1410it [19:30,  1.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1411it [19:31,  1.58it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1412it [19:32,  1.35it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1413it [19:32,  1.49it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1414it [19:33,  1.45it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1415it [19:34,  1.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1416it [19:35,  1.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1417it [19:37,  1.07s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1418it [19:37,  1.07it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1419it [19:38,  1.18it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1420it [19:39,  1.07it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1421it [19:40,  1.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1422it [19:40,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1423it [19:42,  1.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1424it [19:42,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1425it [19:43,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1426it [19:43,  1.49it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1427it [19:44,  1.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1428it [19:45,  1.58it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1429it [19:45,  1.62it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1430it [19:46,  1.56it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1431it [19:47,  1.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1432it [19:47,  1.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1433it [19:48,  1.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1434it [19:49,  1.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1435it [19:49,  1.62it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1436it [19:50,  1.41it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1437it [19:51,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1438it [19:52,  1.31it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1439it [19:52,  1.41it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1440it [19:53,  1.61it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1441it [19:54,  1.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1442it [19:56,  1.12s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1443it [19:57,  1.06s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1444it [19:58,  1.06it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1445it [19:59,  1.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1446it [20:00,  1.12s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1447it [20:00,  1.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1448it [20:02,  1.05s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1449it [20:03,  1.00it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1450it [20:04,  1.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1451it [20:05,  1.01s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1452it [20:06,  1.05it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1453it [20:06,  1.27it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1454it [20:06,  1.51it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1455it [20:07,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1456it [20:08,  1.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1457it [20:08,  1.59it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1458it [20:09,  1.82it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1459it [20:10,  1.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1460it [20:11,  1.04it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1461it [20:12,  1.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1462it [20:13,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1463it [20:14,  1.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1464it [20:15,  1.10s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1465it [20:16,  1.04it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1466it [20:17,  1.00it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1467it [20:18,  1.04s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1468it [20:19,  1.03it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1469it [20:19,  1.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1470it [20:20,  1.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1471it [20:21,  1.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1472it [20:22,  1.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1473it [20:22,  1.35it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1474it [20:23,  1.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1475it [20:24,  1.46it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1476it [20:25,  1.05it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1477it [20:26,  1.04it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1478it [20:26,  1.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1479it [20:27,  1.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1480it [20:27,  1.60it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1481it [20:28,  1.61it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1482it [20:28,  1.73it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1483it [20:29,  1.67it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1484it [20:31,  1.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1485it [20:31,  1.23it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1486it [20:32,  1.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1487it [20:32,  1.72it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1488it [20:33,  1.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1489it [20:34,  1.45it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1490it [20:34,  1.63it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1491it [20:35,  1.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1492it [20:35,  1.86it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1493it [20:36,  1.85it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1494it [20:37,  1.62it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1495it [20:38,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1496it [20:38,  1.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1497it [20:39,  1.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1498it [20:40,  1.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1499it [20:41,  1.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1500it [20:41,  1.21it/s]

# %%
name  = 'test_pred_en_with_term_find.txt'

test_pred_en_df = []
for i in test_pred_en_with_term_find:
    test_pred_en_df.append('\t'.join(i))


test_pred_en_df = pd.DataFrame(test_pred_en_df)
test_pred_en_df.to_csv(name, header=None, index=None)

# %%
# !python /home/jovyan/work/debuged_task9-scorer.py /home/jovyan/work/SemEval2018-Task9/test/gold/1A.english.test.gold.txt test_pred_en_with_term_find.txt
# Out:
# MRR: 0.3551455766455761
# MAP: 0.23321399933399914
# P@1: 0.258
# P@3: 0.19966666666666685
# P@5: 0.2013222222222211
# P@15: 0.27276278721278713

# %%
embading_with_term_find = """
MRR: 0.3551455766455761
MAP: 0.23321399933399914
P@1: 0.258
P@3: 0.19966666666666685
P@5: 0.2013222222222211
P@15: 0.27276278721278713
find hyponyms for hyperonym ... with relationship [Cncept, Entity], target:
""" 


embading_with_term_find_table = answers(embading_with_term_find)
embading_with_term_find_table
# Out:
#                                                         MRR      MAP    P@1  \
# prefix
# find hyponyms for hyperonym ... with relationsh...  0.35515  0.23321  0.258
#
#                                                         P@3      P@5     P@15
# prefix
# find hyponyms for hyperonym ... with relationsh...  0.19967  0.20132  0.27276

# %% [markdown]
# # Increase the size of batch with standart embadding

# %%
# !nvidia-smi
# Out:
# Mon Feb 27 10:24:15 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.86.01    Driver Version: 515.86.01    CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:E1:00.0 Off |                  N/A |
# |  0%   25C    P8    25W / 370W |   6393MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
def QandA_preprocessing(train_features, train_target, test_features, test_target):
    
    train_data_en = train_features.copy()
    train_data_en = 'question: what are hyponyms for hyperonym ' + train_data_en.term + ' ?' + ' | answer: _20_'
    print(train_data_en.head())

    train_gold_en = train_target.copy()
    train_gold_en = train_gold_en.hypernym.str.split('\t').str.join(', ')
    print(train_gold_en.head())
    
    test_data_en = test_features.copy()
    test_data_en = 'question: what are hyponyms for hyperonym ' + test_data_en.term + ' ?' + ' | answer: _20_' 
    print(test_data_en.head())

    test_gold_en = test_target.copy()
    test_gold_en = test_gold_en.hypernym.str.split('\t').str.join(', ')
    print(test_gold_en.head())
    
    return train_data_en, train_gold_en, test_data_en, test_gold_en

train_data_en, train_gold_en, test_data_en, test_gold_en = QandA_preprocessing(train_data_en_data, 
                                                                                 train_gold_en_data, 
                                                                                 test_data_en_data, 
                                                                                 test_gold_en_data)
# Out:
# 0    question: what are hyponyms for hyperonym blac...
# 1    question: what are hyponyms for hyperonym Turo...
# 2    question: what are hyponyms for hyperonym abho...
# 3    question: what are hyponyms for hyperonym trop...
# 4    question: what are hyponyms for hyperonym mili...
# Name: term, dtype: object
# 0                           homopterous insect, insect
# 1    technical specification, geologic timescale, p...
# 2                      distaste, hatred, hate, disgust
# 3    atmosphere, windstorm, violent storm, air curr...
# 4                                       social control
# Name: hypernym, dtype: object
# 0    question: what are hyponyms for hyperonym mali...
# 1    question: what are hyponyms for hyperonym buck...
# 2    question: what are hyponyms for hyperonym spel...
# 3    question: what are hyponyms for hyperonym quo ...
# 4    question: what are hyponyms for hyperonym Jeff...
# Name: term, dtype: object
# 0       malevolence, distaste, hatred, hate, malignity
# 1                                           body armor
# 2                    exploration, adventurer, explorer
# 3    proceedings, legal proceedings, proceeding, du...
# 4               thrower, baseball player, jock, person
# Name: hypernym, dtype: object

# %%
train_dataset = PairsDataset(tokenizer(train_data_en.tolist()), tokenizer(train_gold_en.tolist()))
test_dataset = PairsDataset(tokenizer(test_data_en.tolist()), tokenizer(test_gold_en.tolist()))
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

args = TrainingArguments(output_dir="t5-finetuned-large", 
                         num_train_epochs=16, 
                         per_device_train_batch_size=16, save_steps=10000)

trainer = Trainer(
    model = model,
    args = args,
    train_dataset = train_dataset,
    eval_dataset = test_dataset,
    tokenizer = tokenizer,
    data_collator = data_collator
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
trainer.train()
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 1500
#   Num Epochs = 16
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1504
#   Number of trainable parameters = 737668096
#     <div>
#
#       <progress value='1504' max='1504' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1504/1504 09:25, Epoch 16/16]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.398800</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.338300</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.299400</td>
#     </tr>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=1504, training_loss=0.34549561824570313, metrics={'train_runtime': 565.5631, 'train_samples_per_second': 42.436, 'train_steps_per_second': 2.659, 'total_flos': 2763293841408000.0, 'train_loss': 0.34549561824570313, 'epoch': 16.0})

# %%
test_pred_en_QA = predict(test_data_en, test_gold_en)
# Out:
# 0it [00:00, ?it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# /opt/conda/lib/python3.10/site-packages/transformers/generation/beam_search.py:198: UserWarning: Passing `max_length` to BeamSearchScorer is deprecated and has no effect. `max_length` should be passed directly to `beam_search(...)`, `beam_sample(...)`, or `group_beam_search(...)`.
#   warnings.warn(
# 1it [00:00,  1.76it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 2it [00:01,  1.78it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 3it [00:02,  1.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 4it [00:02,  1.77it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 5it [00:02,  1.70it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 6it [00:03,  1.95it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 7it [00:03,  1.81it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 8it [00:04,  1.81it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 9it [00:05,  1.74it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 10it [00:06,  1.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 11it [00:06,  1.61it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 12it [00:07,  1.31it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 13it [00:08,  1.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 14it [00:08,  1.45it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 15it [00:09,  1.27it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 16it [00:10,  1.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 17it [00:11,  1.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 18it [00:11,  1.66it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 19it [00:12,  1.84it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 20it [00:12,  1.86it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 21it [00:13,  1.88it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 22it [00:13,  1.62it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 23it [00:14,  1.45it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 24it [00:15,  1.46it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 25it [00:16,  1.23it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 26it [00:17,  1.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 27it [00:17,  1.50it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 28it [00:18,  1.61it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 29it [00:18,  1.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 30it [00:19,  1.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 31it [00:20,  1.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 32it [00:21,  1.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 33it [00:22,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 34it [00:23,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 35it [00:23,  1.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 36it [00:24,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 37it [00:25,  1.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 38it [00:25,  1.56it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 39it [00:26,  1.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 40it [00:26,  1.58it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 41it [00:27,  1.61it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 42it [00:28,  1.76it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 43it [00:28,  1.64it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 44it [00:29,  1.69it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 45it [00:29,  1.75it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 46it [00:30,  1.80it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 47it [00:30,  1.70it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 48it [00:31,  1.84it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 49it [00:31,  1.83it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 50it [00:32,  1.71it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 51it [00:33,  1.70it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 52it [00:33,  1.70it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 53it [00:34,  1.73it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 54it [00:34,  1.78it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 55it [00:35,  1.75it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 56it [00:35,  1.88it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 57it [00:36,  2.07it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 58it [00:36,  2.18it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 59it [00:37,  1.76it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 60it [00:37,  2.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 61it [00:38,  1.49it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 62it [00:39,  1.69it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 63it [00:40,  1.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 64it [00:40,  1.75it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 65it [00:40,  2.00it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 66it [00:41,  1.98it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 67it [00:42,  1.77it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 68it [00:43,  1.18it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 69it [00:44,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 70it [00:44,  1.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 71it [00:44,  1.77it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 72it [00:45,  1.94it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 73it [00:45,  1.94it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 74it [00:47,  1.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 75it [00:47,  1.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 76it [00:48,  1.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 77it [00:49,  1.50it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 78it [00:49,  1.73it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 79it [00:49,  2.03it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 80it [00:50,  1.91it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 81it [00:51,  1.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 82it [00:51,  1.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 83it [00:52,  1.70it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 84it [00:53,  1.44it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 85it [00:54,  1.23it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 86it [00:55,  1.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 87it [00:56,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 88it [00:56,  1.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 89it [00:57,  1.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 90it [00:58,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 91it [00:58,  1.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 92it [00:59,  1.60it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 93it [00:59,  1.79it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 94it [01:00,  1.69it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 95it [01:00,  1.79it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 96it [01:01,  1.80it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 97it [01:01,  1.73it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 98it [01:02,  1.66it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 99it [01:03,  1.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 100it [01:03,  1.75it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 101it [01:04,  1.96it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 102it [01:04,  2.00it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 103it [01:05,  1.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 104it [01:06,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 105it [01:06,  1.50it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 106it [01:07,  1.67it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 107it [01:08,  1.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 108it [01:08,  1.45it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 109it [01:09,  1.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 110it [01:10,  1.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 111it [01:11,  1.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 112it [01:11,  1.59it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 113it [01:12,  1.94it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 114it [01:12,  1.61it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 115it [01:13,  1.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 116it [01:14,  1.51it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 117it [01:15,  1.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 118it [01:15,  1.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 119it [01:16,  1.59it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 120it [01:17,  1.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 121it [01:17,  1.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 122it [01:18,  1.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 123it [01:19,  1.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 124it [01:19,  1.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 125it [01:20,  1.70it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 126it [01:20,  1.87it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 127it [01:21,  1.81it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 128it [01:21,  1.77it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 129it [01:22,  2.07it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 130it [01:22,  1.68it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 131it [01:23,  1.68it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 132it [01:24,  1.56it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 133it [01:24,  1.49it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 134it [01:25,  1.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 135it [01:26,  1.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 136it [01:27,  1.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 137it [01:28,  1.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 138it [01:29,  1.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 139it [01:29,  1.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 140it [01:30,  1.59it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 141it [01:30,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 142it [01:31,  1.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 143it [01:32,  1.60it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 144it [01:32,  1.69it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 145it [01:33,  1.57it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 146it [01:33,  1.66it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 147it [01:34,  1.67it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 148it [01:35,  1.56it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 149it [01:35,  1.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 150it [01:36,  1.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 151it [01:37,  1.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 152it [01:37,  1.84it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 153it [01:38,  1.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 154it [01:38,  1.77it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 155it [01:39,  1.97it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 156it [01:39,  1.84it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 157it [01:40,  1.69it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 158it [01:40,  1.90it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 159it [01:41,  1.60it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 160it [01:42,  1.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 161it [01:42,  1.64it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 162it [01:43,  1.57it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 163it [01:44,  1.69it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 164it [01:44,  1.83it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 165it [01:44,  2.03it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 166it [01:45,  1.57it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 167it [01:46,  1.63it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 168it [01:47,  1.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 169it [01:47,  1.57it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 170it [01:48,  1.42it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 171it [01:49,  1.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 172it [01:49,  1.89it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 173it [01:49,  1.94it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 174it [01:50,  1.86it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 175it [01:51,  1.73it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 176it [01:51,  1.75it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 177it [01:52,  1.96it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 178it [01:53,  1.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 179it [01:53,  1.71it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 180it [01:54,  1.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 181it [01:54,  1.66it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 182it [01:55,  1.61it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 183it [01:56,  1.60it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 184it [01:56,  1.66it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 185it [01:57,  1.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 186it [01:58,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 187it [01:58,  1.44it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 188it [01:59,  1.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 189it [02:00,  1.31it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 190it [02:01,  1.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 191it [02:01,  1.67it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 192it [02:01,  1.68it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 193it [02:02,  1.89it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 194it [02:02,  2.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 195it [02:03,  1.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 196it [02:04,  1.80it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 197it [02:04,  1.96it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 198it [02:05,  1.86it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 199it [02:05,  1.97it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 200it [02:06,  1.84it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 201it [02:06,  2.18it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 202it [02:06,  2.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 203it [02:07,  2.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 204it [02:07,  2.31it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 205it [02:08,  1.99it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 206it [02:08,  2.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 207it [02:09,  2.18it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 208it [02:09,  2.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 209it [02:10,  2.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 210it [02:10,  2.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 211it [02:11,  2.11it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 212it [02:11,  2.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 213it [02:11,  2.05it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 214it [02:12,  1.83it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 215it [02:13,  1.93it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 216it [02:14,  1.57it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 217it [02:14,  1.44it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 218it [02:15,  1.67it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 219it [02:16,  1.50it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 220it [02:17,  1.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 221it [02:17,  1.41it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 222it [02:18,  1.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 223it [02:19,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 224it [02:19,  1.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 225it [02:20,  1.51it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 226it [02:20,  1.51it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 227it [02:21,  1.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 228it [02:21,  1.76it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 229it [02:22,  1.67it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 230it [02:23,  1.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 231it [02:23,  1.63it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 232it [02:24,  1.85it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 233it [02:24,  1.87it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 234it [02:25,  1.89it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 235it [02:25,  1.75it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 236it [02:26,  1.96it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 237it [02:27,  1.66it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 238it [02:27,  1.88it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 239it [02:27,  2.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 240it [02:28,  1.89it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 241it [02:29,  1.44it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 242it [02:29,  1.70it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 243it [02:30,  1.70it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 244it [02:31,  1.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 245it [02:32,  1.51it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 246it [02:34,  1.04s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 247it [02:34,  1.07it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 248it [02:35,  1.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 249it [02:35,  1.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 250it [02:36,  1.62it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 251it [02:36,  1.74it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 252it [02:37,  1.72it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 253it [02:37,  1.89it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 254it [02:39,  1.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 255it [02:39,  1.35it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 256it [02:40,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 257it [02:40,  1.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 258it [02:42,  1.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 259it [02:43,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 260it [02:43,  1.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 261it [02:44,  1.31it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 262it [02:44,  1.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 263it [02:45,  1.67it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 264it [02:45,  1.93it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 265it [02:46,  2.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 266it [02:46,  2.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 267it [02:47,  1.51it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 268it [02:48,  1.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 269it [02:48,  1.58it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 270it [02:49,  1.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 271it [02:50,  1.62it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 272it [02:50,  1.70it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 273it [02:51,  1.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 274it [02:52,  1.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 275it [02:53,  1.27it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 276it [02:54,  1.23it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 277it [02:54,  1.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 278it [02:56,  1.10s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 279it [02:58,  1.12s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 280it [02:58,  1.04it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# ...
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1407it [14:39,  1.56it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1408it [14:40,  1.44it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1409it [14:40,  1.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1410it [14:41,  1.49it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1411it [14:42,  1.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1412it [14:42,  1.45it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1413it [14:43,  1.72it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1414it [14:43,  1.94it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1415it [14:44,  1.71it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1416it [14:44,  1.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1417it [14:45,  1.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1418it [14:46,  1.62it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1419it [14:46,  1.84it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1420it [14:47,  1.35it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1421it [14:48,  1.62it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1422it [14:48,  1.74it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1423it [14:49,  1.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1424it [14:49,  1.66it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1425it [14:50,  1.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1426it [14:50,  1.86it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1427it [14:51,  1.73it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1428it [14:52,  1.68it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1429it [14:52,  1.68it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1430it [14:53,  1.78it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1431it [14:53,  1.86it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1432it [14:54,  1.97it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1433it [14:54,  2.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1434it [14:55,  2.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1435it [14:55,  1.88it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1436it [14:56,  1.68it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1437it [14:57,  1.75it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1438it [14:57,  1.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1439it [14:58,  1.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1440it [14:58,  1.71it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1441it [14:59,  1.64it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1442it [15:01,  1.18it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1443it [15:01,  1.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1444it [15:02,  1.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1445it [15:02,  1.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1446it [15:03,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1447it [15:04,  1.51it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1448it [15:04,  1.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1449it [15:05,  1.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1450it [15:06,  1.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1451it [15:07,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1452it [15:07,  1.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1453it [15:08,  1.62it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1454it [15:08,  1.89it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1455it [15:09,  1.62it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1456it [15:09,  1.80it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1457it [15:10,  1.96it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1458it [15:10,  2.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1459it [15:11,  2.11it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1460it [15:11,  2.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1461it [15:12,  2.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1462it [15:12,  2.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1463it [15:13,  1.46it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1464it [15:14,  1.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1465it [15:15,  1.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1466it [15:15,  1.49it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1467it [15:16,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1468it [15:17,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1469it [15:18,  1.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1470it [15:18,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1471it [15:19,  1.42it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1472it [15:20,  1.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1473it [15:20,  1.68it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1474it [15:20,  1.94it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1475it [15:21,  1.82it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1476it [15:22,  1.74it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1477it [15:23,  1.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1478it [15:23,  1.63it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1479it [15:23,  1.93it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1480it [15:24,  1.81it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1481it [15:25,  1.74it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1482it [15:25,  1.69it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1483it [15:26,  1.57it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1484it [15:27,  1.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1485it [15:28,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1486it [15:28,  1.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1487it [15:29,  1.76it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1488it [15:29,  1.92it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1489it [15:30,  1.67it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1490it [15:30,  1.78it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1491it [15:31,  1.79it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1492it [15:31,  2.08it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1493it [15:32,  2.08it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1494it [15:32,  2.08it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1495it [15:33,  1.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1496it [15:34,  1.57it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1497it [15:35,  1.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1498it [15:35,  1.41it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1499it [15:36,  1.59it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1500it [15:36,  1.60it/s]

# %%
name  = 'test_pred_en_QA.txt'

test_pred_en_df = []
for i in test_pred_en_QA:
    test_pred_en_df.append('\t'.join(i))


test_pred_en_df = pd.DataFrame(test_pred_en_df)
test_pred_en_df.to_csv(name, header=None, index=None)

# %%
# !python /home/jovyan/work/debuged_task9-scorer.py /home/jovyan/work/SemEval2018-Task9/test/gold/1A.english.test.gold.txt test_pred_en_QA.txt
# Out:
# MRR: 0.39486768601768607
# MAP: 0.25371332383665746
# P@1: 0.31
# P@3: 0.21866666666666673
# P@5: 0.21817777777777636
# P@15: 0.29226473341473297

# %%
test_pred_en_df[0].str.split('\t').apply(lambda x: x[:20]).str.join('\t').to_csv('pruned.txt', header=None, index=None)

# %%
# !python debuged_task9-scorer.py SemEval2018-Task9/test/gold/1A.english.test.gold.txt pruned.txt
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# MRR: 0.3987962574462576
# MAP: 0.25522200108533477
# P@1: 0.31466666666666665
# P@3: 0.2202222222222222
# P@5: 0.21941111111110967
# P@15: 0.293409971509971

# %%
test_pred_en_QA = """
MRR: 0.39486768601768607
MAP: 0.25371332383665746
P@1: 0.31
P@3: 0.21866666666666673
P@5: 0.21817777777777636
P@15: 0.29226473341473297
Q&A
""" 


standart_embading_with_batch_size_32_table = answers(test_pred_en_QA)
standart_embading_with_batch_size_32_table
# Out:
#                MRR      MAP   P@1      P@3      P@5     P@15
# embadding
# Q&A        0.39487  0.25371  0.31  0.21867  0.21818  0.29226

# %%
test_pred_en_QA_pruned = """
MRR: 0.3987962574462576
MAP: 0.25522200108533477
P@1: 0.31466666666666665
P@3: 0.2202222222222222
P@5: 0.21941111111110967
P@15: 0.293409971509971
Q&A_Pruned
""" 


standart_embading_QA_pruned = answers(test_pred_en_QA_pruned)
standart_embading_QA_pruned
# Out:
#                MRR      MAP      P@1      P@3      P@5     P@15
# embadding
# Q&A_Pruned  0.3988  0.25522  0.31467  0.22022  0.21941  0.29341

# %%
cleanup()

del trainer

# !nvidia-smi
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Mon Feb 27 12:50:41 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.86.01    Driver Version: 515.86.01    CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:E1:00.0 Off |                  N/A |
# |  0%   29C    P2    70W / 370W |  12895MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Pruning embadding

# %%
def QA_with_closing_s(train_features, train_target, test_features, test_target):
    
    train_data_en = train_features.copy()
    train_data_en = 'answer question: what are hyponyms for hyperonym: ' + train_data_en.term + ' </s>"' + ' , target:'
    print(train_data_en.head())

    train_gold_en = train_target.copy()
    train_gold_en = train_gold_en.hypernym.str.split('\t').str.join(', ')
    print(train_gold_en.head())
    
    test_data_en = test_features.copy()
    test_data_en = 'answer question: what are hyponyms for hyperonym: ' + test_features.term + ' </s>"' + ' , target:'
    print(test_data_en.head())

    test_gold_en = test_target.copy()
    test_gold_en = test_gold_en.hypernym.str.split('\t').str.join(', ')
    print(test_gold_en.head())
    
    return train_data_en, train_gold_en, test_data_en, test_gold_en

# %%
train_data_en, train_gold_en, test_data_en, test_gold_en = QA_with_closing_s(train_data_en_data, 
                                                                                 train_gold_en_data, 
                                                                                 test_data_en_data, 
                                                                                 test_gold_en_data)
# Out:
# 0    answer question: what are hyponyms for hyperon...
# 1    answer question: what are hyponyms for hyperon...
# 2    answer question: what are hyponyms for hyperon...
# 3    answer question: what are hyponyms for hyperon...
# 4    answer question: what are hyponyms for hyperon...
# Name: term, dtype: object
# 0                           homopterous insect, insect
# 1    technical specification, geologic timescale, p...
# 2                      distaste, hatred, hate, disgust
# 3    atmosphere, windstorm, violent storm, air curr...
# 4                                       social control
# Name: hypernym, dtype: object
# 0    answer question: what are hyponyms for hyperon...
# 1    answer question: what are hyponyms for hyperon...
# 2    answer question: what are hyponyms for hyperon...
# 3    answer question: what are hyponyms for hyperon...
# 4    answer question: what are hyponyms for hyperon...
# Name: term, dtype: object
# 0       malevolence, distaste, hatred, hate, malignity
# 1                                           body armor
# 2                    exploration, adventurer, explorer
# 3    proceedings, legal proceedings, proceeding, du...
# 4               thrower, baseball player, jock, person
# Name: hypernym, dtype: object

# %%
train_dataset = PairsDataset(tokenizer(train_data_en.tolist()), tokenizer(train_gold_en.tolist()))
test_dataset = PairsDataset(tokenizer(test_data_en.tolist()), tokenizer(test_gold_en.tolist()))
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

args = TrainingArguments(output_dir="t5-finetuned-large", 
                         num_train_epochs=16, 
                         per_device_train_batch_size=16, save_steps=10000)

trainer = Trainer(
    model = model,
    args = args,
    train_dataset = train_dataset,
    eval_dataset = test_dataset,
    tokenizer = tokenizer,
    data_collator = data_collator
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
trainer.train()
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 1500
#   Num Epochs = 16
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1504
#   Number of trainable parameters = 737668096
#     <div>
#
#       <progress value='1504' max='1504' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1504/1504 09:25, Epoch 16/16]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.203900</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.164900</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.138700</td>
#     </tr>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=1504, training_loss=0.16911852993863694, metrics={'train_runtime': 565.9416, 'train_samples_per_second': 42.407, 'train_steps_per_second': 2.658, 'total_flos': 2661807249408000.0, 'train_loss': 0.16911852993863694, 'epoch': 16.0})

# %%
# !nvidia-smi
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Mon Feb 27 13:54:49 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.86.01    Driver Version: 515.86.01    CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:E1:00.0 Off |                  N/A |
# | 74%   53C    P2   255W / 370W |  24243MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
test_pred_en_QA_with_closing_s = predict(test_data_en, test_gold_en)
# Out:
# 0it [00:00, ?it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# /opt/conda/lib/python3.10/site-packages/transformers/generation/beam_search.py:198: UserWarning: Passing `max_length` to BeamSearchScorer is deprecated and has no effect. `max_length` should be passed directly to `beam_search(...)`, `beam_sample(...)`, or `group_beam_search(...)`.
#   warnings.warn(
# 1it [00:00,  1.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 2it [00:01,  1.56it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 3it [00:01,  1.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 4it [00:02,  1.67it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 5it [00:03,  1.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 6it [00:03,  1.71it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 7it [00:05,  1.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 8it [00:05,  1.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 9it [00:06,  1.50it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 10it [00:07,  1.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 11it [00:07,  1.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 12it [00:08,  1.18it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 13it [00:09,  1.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 14it [00:10,  1.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 15it [00:11,  1.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 16it [00:12,  1.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 17it [00:12,  1.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 18it [00:13,  1.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 19it [00:13,  1.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 20it [00:14,  1.46it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 21it [00:15,  1.67it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 22it [00:16,  1.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 23it [00:17,  1.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 24it [00:18,  1.05it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 25it [00:21,  1.53s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 26it [00:22,  1.36s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 27it [00:22,  1.09s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 28it [00:23,  1.11s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 29it [00:24,  1.03it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 30it [00:25,  1.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 31it [00:27,  1.27s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 32it [00:30,  1.67s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 33it [00:30,  1.33s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 34it [00:31,  1.11s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 35it [00:32,  1.09s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 36it [00:33,  1.01s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 37it [00:33,  1.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 38it [00:34,  1.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 39it [00:35,  1.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 40it [00:36,  1.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 41it [00:37,  1.08it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 42it [00:37,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 43it [00:38,  1.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 44it [00:39,  1.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 45it [00:40,  1.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 46it [00:40,  1.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 47it [00:42,  1.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 48it [00:42,  1.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 49it [00:43,  1.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 50it [00:44,  1.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 51it [00:45,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 52it [00:45,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 53it [00:46,  1.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 54it [00:47,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 55it [00:47,  1.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 56it [00:48,  1.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 57it [00:49,  1.45it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 58it [00:50,  1.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 59it [00:50,  1.44it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 60it [00:51,  1.60it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 61it [00:52,  1.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 62it [00:53,  1.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 63it [00:54,  1.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 64it [00:54,  1.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 65it [00:55,  1.56it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 66it [00:55,  1.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 67it [00:56,  1.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 68it [00:57,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 69it [00:58,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 70it [00:59,  1.11it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 71it [00:59,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 72it [01:00,  1.50it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 73it [01:01,  1.50it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 74it [01:02,  1.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 75it [01:04,  1.09s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 76it [01:05,  1.19s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 77it [01:06,  1.18s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 78it [01:07,  1.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 79it [01:07,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 80it [01:08,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 81it [01:09,  1.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 82it [01:10,  1.06it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 83it [01:11,  1.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 84it [01:12,  1.07s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 85it [01:14,  1.12s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 86it [01:14,  1.03it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 87it [01:15,  1.01s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 88it [01:16,  1.06s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 89it [01:17,  1.03s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 90it [01:18,  1.03it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 91it [01:19,  1.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 92it [01:19,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 93it [01:20,  1.46it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 94it [01:21,  1.23it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 95it [01:22,  1.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 96it [01:22,  1.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 97it [01:24,  1.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 98it [01:25,  1.07it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 99it [01:26,  1.02s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 100it [01:26,  1.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 101it [01:27,  1.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 102it [01:27,  1.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 103it [01:28,  1.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 104it [01:30,  1.07it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 105it [01:30,  1.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 106it [01:31,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 107it [01:32,  1.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 108it [01:32,  1.35it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 109it [01:33,  1.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 110it [01:35,  1.00s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 111it [01:35,  1.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 112it [01:36,  1.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 113it [01:36,  1.45it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 114it [01:37,  1.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 115it [01:39,  1.14s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 116it [01:40,  1.06s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 117it [01:41,  1.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 118it [01:42,  1.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 119it [01:43,  1.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 120it [01:43,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 121it [01:44,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 122it [01:45,  1.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 123it [01:45,  1.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 124it [01:46,  1.41it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 125it [01:47,  1.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 126it [01:48,  1.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 127it [01:48,  1.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 128it [01:49,  1.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 129it [01:50,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 130it [01:51,  1.11it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 131it [01:52,  1.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 132it [01:53,  1.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 133it [01:54,  1.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 134it [01:55,  1.05it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 135it [01:55,  1.18it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 136it [01:57,  1.07it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 137it [01:58,  1.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 138it [01:58,  1.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 139it [01:59,  1.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 140it [02:00,  1.27it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 141it [02:01,  1.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 142it [02:02,  1.03it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 143it [02:02,  1.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 144it [02:03,  1.35it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 145it [02:04,  1.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 146it [02:04,  1.39it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 147it [02:05,  1.44it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 148it [02:06,  1.50it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 149it [02:07,  1.27it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 150it [02:09,  1.12s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 151it [02:09,  1.05it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 152it [02:10,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 153it [02:11,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 154it [02:11,  1.40it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 155it [02:12,  1.45it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 156it [02:13,  1.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 157it [02:14,  1.03it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 158it [02:15,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 159it [02:15,  1.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 160it [02:16,  1.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 161it [02:17,  1.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 162it [02:18,  1.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 163it [02:19,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 164it [02:19,  1.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 165it [02:20,  1.41it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 166it [02:21,  1.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 167it [02:22,  1.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 168it [02:22,  1.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 169it [02:23,  1.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 170it [02:24,  1.18it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 171it [02:25,  1.31it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 172it [02:25,  1.58it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 173it [02:26,  1.73it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 174it [02:26,  1.67it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 175it [02:27,  1.74it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 176it [02:28,  1.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 177it [02:28,  1.71it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 178it [02:29,  1.46it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 179it [02:29,  1.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 180it [02:31,  1.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 181it [02:32,  1.04it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 182it [02:33,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 183it [02:33,  1.35it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 184it [02:34,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 185it [02:35,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 186it [02:36,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 187it [02:36,  1.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 188it [02:37,  1.49it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 189it [02:38,  1.06it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 190it [02:39,  1.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 191it [02:39,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 192it [02:40,  1.35it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 193it [02:41,  1.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 194it [02:41,  1.57it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 195it [02:43,  1.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 196it [02:43,  1.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 197it [02:44,  1.23it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 198it [02:45,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 199it [02:46,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 200it [02:46,  1.42it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 201it [02:46,  1.72it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 202it [02:47,  1.88it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 203it [02:47,  1.77it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 204it [02:48,  1.73it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 205it [02:49,  1.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 206it [02:50,  1.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 207it [02:50,  1.64it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 208it [02:51,  1.74it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 209it [02:51,  1.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 210it [02:52,  1.78it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 211it [02:52,  1.71it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 212it [02:53,  1.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 213it [02:54,  1.55it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 214it [02:54,  1.71it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 215it [02:55,  2.00it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 216it [02:56,  1.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 217it [02:57,  1.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 218it [02:57,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 219it [02:59,  1.06s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 220it [03:01,  1.17s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 221it [03:01,  1.02it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 222it [03:02,  1.20it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 223it [03:02,  1.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 224it [03:04,  1.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 225it [03:04,  1.27it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 226it [03:05,  1.18it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 227it [03:06,  1.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 228it [03:06,  1.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 229it [03:07,  1.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 230it [03:08,  1.35it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 231it [03:09,  1.07it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 232it [03:10,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 233it [03:10,  1.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 234it [03:11,  1.46it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 235it [03:11,  1.53it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 236it [03:12,  1.75it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 237it [03:13,  1.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 238it [03:14,  1.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 239it [03:15,  1.41it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 240it [03:15,  1.42it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 241it [03:16,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 242it [03:16,  1.60it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 243it [03:17,  1.51it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 244it [03:19,  1.14s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 245it [03:20,  1.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 246it [03:22,  1.27s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 247it [03:23,  1.20s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 248it [03:23,  1.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 249it [03:24,  1.05it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 250it [03:25,  1.34it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 251it [03:25,  1.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 252it [03:26,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 253it [03:26,  1.47it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 254it [03:29,  1.23s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 255it [03:29,  1.05it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 256it [03:31,  1.06s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 257it [03:31,  1.07it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 258it [03:33,  1.14s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 259it [03:34,  1.07s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 260it [03:35,  1.18s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 261it [03:36,  1.15s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 262it [03:37,  1.04s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 263it [03:38,  1.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 264it [03:38,  1.18it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 265it [03:39,  1.46it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 266it [03:39,  1.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 267it [03:41,  1.04s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 268it [03:42,  1.04s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 269it [03:43,  1.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 270it [03:44,  1.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 271it [03:44,  1.31it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 272it [03:45,  1.42it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 273it [03:46,  1.23it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 274it [03:47,  1.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 275it [03:48,  1.16it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 276it [03:48,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 277it [03:50,  1.04s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 278it [03:52,  1.34s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 279it [03:53,  1.34s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 280it [03:54,  1.20s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# ...
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1407it [19:31,  1.18it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1408it [19:31,  1.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1409it [19:32,  1.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1410it [19:33,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1411it [19:34,  1.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1412it [19:35,  1.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1413it [19:36,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1414it [19:36,  1.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1415it [19:37,  1.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1416it [19:38,  1.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1417it [19:39,  1.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1418it [19:39,  1.44it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1419it [19:40,  1.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1420it [19:42,  1.05it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1421it [19:42,  1.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1422it [19:44,  1.02s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1423it [19:45,  1.02s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1424it [19:45,  1.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1425it [19:46,  1.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1426it [19:47,  1.37it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1427it [19:47,  1.27it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1428it [19:48,  1.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1429it [19:49,  1.29it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1430it [19:50,  1.30it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1431it [19:50,  1.42it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1432it [19:51,  1.33it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1433it [19:52,  1.36it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1434it [19:52,  1.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1435it [19:54,  1.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1436it [19:55,  1.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1437it [19:55,  1.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1438it [19:56,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1439it [19:57,  1.26it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1440it [19:57,  1.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1441it [19:58,  1.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1442it [20:00,  1.04it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1443it [20:00,  1.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1444it [20:01,  1.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1445it [20:02,  1.28it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1446it [20:03,  1.09it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1447it [20:04,  1.14it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1448it [20:05,  1.04s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1449it [20:07,  1.17s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1450it [20:08,  1.19s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1451it [20:09,  1.11s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1452it [20:09,  1.04it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1453it [20:10,  1.27it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1454it [20:10,  1.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1455it [20:11,  1.45it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1456it [20:11,  1.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1457it [20:12,  1.72it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1458it [20:12,  1.97it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1459it [20:13,  1.69it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1460it [20:15,  1.01it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1461it [20:15,  1.21it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1462it [20:16,  1.38it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1463it [20:17,  1.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1464it [20:18,  1.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1465it [20:19,  1.22it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1466it [20:20,  1.10it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1467it [20:21,  1.04it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1468it [20:22,  1.16s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1469it [20:23,  1.07it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1470it [20:24,  1.08it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1471it [20:25,  1.07it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1472it [20:26,  1.13it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1473it [20:26,  1.12it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1474it [20:27,  1.19it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1475it [20:28,  1.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1476it [20:29,  1.15it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1477it [20:30,  1.02s/it]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1478it [20:31,  1.17it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1479it [20:31,  1.43it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1480it [20:32,  1.61it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1481it [20:32,  1.75it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1482it [20:32,  2.00it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1483it [20:33,  1.68it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1484it [20:34,  1.48it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1485it [20:34,  1.65it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1486it [20:35,  1.79it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1487it [20:35,  1.91it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1488it [20:36,  1.66it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1489it [20:37,  1.54it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1490it [20:38,  1.50it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1491it [20:38,  1.52it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1492it [20:39,  1.75it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1493it [20:39,  1.69it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1494it [20:40,  1.56it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1495it [20:41,  1.25it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1496it [20:42,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1497it [20:43,  1.32it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1498it [20:44,  1.18it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1499it [20:44,  1.24it/s]Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# 1500it [20:45,  1.20it/s]

# %%
name  = 'QA_with_closing_s.txt'

test_pred_en_df = []
for i in test_pred_en_QA_with_closing_s:
    test_pred_en_df.append('\t'.join(i))


test_pred_en_df = pd.DataFrame(test_pred_en_df)
test_pred_en_df.to_csv(name, header=None, index=None)


# !python debuged_task9-scorer.py SemEval2018-Task9/test/gold/1A.english.test.gold.txt QA_with_closing_s.txt
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# MRR: 0.37523532208532173
# MAP: 0.2431501325834664
# P@1: 0.2826666666666667
# P@3: 0.2108888888888888
# P@5: 0.20878888888888772
# P@15: 0.28244743404743383

# %%
QA_with_closing_s = """
MRR: 0.37523532208532173
MAP: 0.2431501325834664
P@1: 0.2826666666666667
P@3: 0.2108888888888888
P@5: 0.20878888888888772
P@15: 0.28244743404743383
QA_with_closing_s
""" 


QA_with_closing_s_table = answers(QA_with_closing_s)
QA_with_closing_s_table
# Out:
#                        MRR      MAP      P@1      P@3      P@5     P@15
# embadding
# QA_with_closing_s  0.37524  0.24315  0.28267  0.21089  0.20879  0.28245

# %%
cleanup()

del trainer

# !nvidia-smi
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Mon Feb 27 14:16:58 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.86.01    Driver Version: 515.86.01    CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:E1:00.0 Off |                  N/A |
# |  0%   35C    P2    96W / 370W |  13219MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Result

# %%
def highlight_max(s, props=''):
    return np.where(s == np.nanmax(s.values), props, '')

def highlight_min(s, props=''):
    return np.where(s == np.nanmin(s.values), props, '')




metrics_table = pd.concat([embading_standard_table,
                           embading_find_hyponyms_uppercase_table, 
                           embading_find_hyponyms_lowercase_table,            
                           embading_with_term_find_table, 
                           standart_embading_with_batch_size_32_table, 
                           standart_embading_QA_pruned, 
                           test_pred_en_QA_single_table, 
                           QA_with_closing_s_table])



metrics_table = metrics_table.style.apply(highlight_max, 
                                          props='color:white; background-color:#1FC29D', axis=0).apply(highlight_min, props='color:white; background-color:#FF5555', axis=0)
metrics_table
# Out:
# <style type="text/css">
# #T_8d4ad_row1_col0, #T_8d4ad_row1_col2, #T_8d4ad_row1_col3, #T_8d4ad_row1_col4, #T_8d4ad_row5_col1, #T_8d4ad_row5_col5 {
#   color: white;
#   background-color: #1FC29D;
# }
# #T_8d4ad_row1_col5, #T_8d4ad_row3_col0, #T_8d4ad_row3_col1, #T_8d4ad_row3_col2, #T_8d4ad_row3_col3, #T_8d4ad_row3_col4 {
#   color: white;
#   background-color: #FF5555;
# }
# </style>
# <table id="T_8d4ad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d4ad_level0_col0" class="col_heading level0 col0" >MRR</th>
#       <th id="T_8d4ad_level0_col1" class="col_heading level0 col1" >MAP</th>
#       <th id="T_8d4ad_level0_col2" class="col_heading level0 col2" >P@1</th>
#       <th id="T_8d4ad_level0_col3" class="col_heading level0 col3" >P@3</th>
#       <th id="T_8d4ad_level0_col4" class="col_heading level0 col4" >P@5</th>
#       <th id="T_8d4ad_level0_col5" class="col_heading level0 col5" >P@15</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >embadding</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d4ad_level0_row0" class="row_heading level0 row0" >embading_standard</th>
#       <td id="T_8d4ad_row0_col0" class="data row0 col0" >0.367800</td>
#       <td id="T_8d4ad_row0_col1" class="data row0 col1" >0.241990</td>
#       <td id="T_8d4ad_row0_col2" class="data row0 col2" >0.284670</td>
#       <td id="T_8d4ad_row0_col3" class="data row0 col3" >0.202780</td>
#       <td id="T_8d4ad_row0_col4" class="data row0 col4" >0.208040</td>
#       <td id="T_8d4ad_row0_col5" class="data row0 col5" >0.281400</td>
#     </tr>
#     <tr>
#       <th id="T_8d4ad_level0_row1" class="row_heading level0 row1" >embading_find_hyponyms_uppercase</th>
#       <td id="T_8d4ad_row1_col0" class="data row1 col0" >0.406530</td>
#       <td id="T_8d4ad_row1_col1" class="data row1 col1" >0.252540</td>
#       <td id="T_8d4ad_row1_col2" class="data row1 col2" >0.321330</td>
#       <td id="T_8d4ad_row1_col3" class="data row1 col3" >0.226670</td>
#       <td id="T_8d4ad_row1_col4" class="data row1 col4" >0.223430</td>
#       <td id="T_8d4ad_row1_col5" class="data row1 col5" >0.271600</td>
#     </tr>
#     <tr>
#       <th id="T_8d4ad_level0_row2" class="row_heading level0 row2" >embading_find_hyponyms_lowercase</th>
#       <td id="T_8d4ad_row2_col0" class="data row2 col0" >0.384400</td>
#       <td id="T_8d4ad_row2_col1" class="data row2 col1" >0.247430</td>
#       <td id="T_8d4ad_row2_col2" class="data row2 col2" >0.298000</td>
#       <td id="T_8d4ad_row2_col3" class="data row2 col3" >0.214330</td>
#       <td id="T_8d4ad_row2_col4" class="data row2 col4" >0.216970</td>
#       <td id="T_8d4ad_row2_col5" class="data row2 col5" >0.276820</td>
#     </tr>
#     <tr>
#       <th id="T_8d4ad_level0_row3" class="row_heading level0 row3" >emadding_with_term_and_find_prefix</th>
#       <td id="T_8d4ad_row3_col0" class="data row3 col0" >0.355150</td>
#       <td id="T_8d4ad_row3_col1" class="data row3 col1" >0.233210</td>
#       <td id="T_8d4ad_row3_col2" class="data row3 col2" >0.258000</td>
#       <td id="T_8d4ad_row3_col3" class="data row3 col3" >0.199670</td>
#       <td id="T_8d4ad_row3_col4" class="data row3 col4" >0.201320</td>
#       <td id="T_8d4ad_row3_col5" class="data row3 col5" >0.272760</td>
#     </tr>
#     <tr>
#       <th id="T_8d4ad_level0_row4" class="row_heading level0 row4" >Q&A</th>
#       <td id="T_8d4ad_row4_col0" class="data row4 col0" >0.394870</td>
#       <td id="T_8d4ad_row4_col1" class="data row4 col1" >0.253710</td>
#       <td id="T_8d4ad_row4_col2" class="data row4 col2" >0.310000</td>
#       <td id="T_8d4ad_row4_col3" class="data row4 col3" >0.218670</td>
#       <td id="T_8d4ad_row4_col4" class="data row4 col4" >0.218180</td>
#       <td id="T_8d4ad_row4_col5" class="data row4 col5" >0.292260</td>
#     </tr>
#     <tr>
#       <th id="T_8d4ad_level0_row5" class="row_heading level0 row5" >Q&A_Pruned</th>
#       <td id="T_8d4ad_row5_col0" class="data row5 col0" >0.398800</td>
#       <td id="T_8d4ad_row5_col1" class="data row5 col1" >0.255220</td>
#       <td id="T_8d4ad_row5_col2" class="data row5 col2" >0.314670</td>
#       <td id="T_8d4ad_row5_col3" class="data row5 col3" >0.220220</td>
#       <td id="T_8d4ad_row5_col4" class="data row5 col4" >0.219410</td>
#       <td id="T_8d4ad_row5_col5" class="data row5 col5" >0.293410</td>
#     </tr>
#     <tr>
#       <th id="T_8d4ad_level0_row6" class="row_heading level0 row6" >Q&A_single</th>
#       <td id="T_8d4ad_row6_col0" class="data row6 col0" >0.378010</td>
#       <td id="T_8d4ad_row6_col1" class="data row6 col1" >0.243530</td>
#       <td id="T_8d4ad_row6_col2" class="data row6 col2" >0.292000</td>
#       <td id="T_8d4ad_row6_col3" class="data row6 col3" >0.203330</td>
#       <td id="T_8d4ad_row6_col4" class="data row6 col4" >0.209310</td>
#       <td id="T_8d4ad_row6_col5" class="data row6 col5" >0.283600</td>
#     </tr>
#     <tr>
#       <th id="T_8d4ad_level0_row7" class="row_heading level0 row7" >QA_with_closing_s</th>
#       <td id="T_8d4ad_row7_col0" class="data row7 col0" >0.375240</td>
#       <td id="T_8d4ad_row7_col1" class="data row7 col1" >0.243150</td>
#       <td id="T_8d4ad_row7_col2" class="data row7 col2" >0.282670</td>
#       <td id="T_8d4ad_row7_col3" class="data row7 col3" >0.210890</td>
#       <td id="T_8d4ad_row7_col4" class="data row7 col4" >0.208790</td>
#       <td id="T_8d4ad_row7_col5" class="data row7 col5" >0.282450</td>
#     </tr>
#   </tbody>
# </table>
